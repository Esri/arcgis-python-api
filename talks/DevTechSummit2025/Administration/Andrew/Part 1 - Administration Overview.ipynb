# %% [markdown]
# #### setup project

# %%
import sys
sys.path.insert(0, r"C:\SVN\geosaurus_master\src")

# %% [markdown]
# # Administering Your GIS Organizations Using ArcGIS API for Python

# %% [markdown]
# ## Overview

# %% [markdown]
# <img src="./img/gettingstarted.jpg" width=700/>
#
# - The ArcGIS ecosystem is vast
# - Organizations can have multiple versions of any product or multiple products to manage
# - How do you manage this?

# %% [markdown]
# ## The Way of the Python

# %% [markdown]
# <img src="./img/waysofscience.jpg" width=700/>

# %% [markdown]
# - The Python API allows administrators to manage, update and control what happens on your server
# - Script from your favorite IDE or Notebook environment
# - Cross platform support

# %% [markdown]
# ## What Can We Manage?

# %% [markdown]
# <table  style='font-family:"Courier New", Courier, monospace; font-size:200%' width=50%>
#
#   <tr>
#     <td>Users</td>
#     <td><img src="./img/users.png", width=50/></td>
#   </tr>
#   <tr>
#     <td>Content</td>
#     <td><img src="./img/content.png", width=50/></td>
#   </tr>
#   <tr>
#     <td>Infrastructure</td>
#     <td><img src="./img/infrastructure.png", width=50/></td>
#   </tr>
#   <tr>
#     <td>Groups</td>
#     <td><img src="./img/groups.png" width=50/></td>
#   </tr>
#
# </table>

# %% [markdown]
# ## Getting Started

# %% [markdown]
# ### Understand the `GIS` Object

# %% [markdown]
# The `GIS` object is the way users connect to ArcGIS Online and/or Enterprise
#
# - It doesn't matter if you are an administrator of a user, we must start here.

# %% [markdown]
# #### Connecting to you `GIS`

# %% [markdown]
# The ArcGIS API for Python support multiple ways of connecting to the `GIS`, which is ArcGIS Online or ArcGIS Enterprise

# %% [markdown]
# ##### Anonymously

# %%
from arcgis.gis import GIS
gis = GIS() #anonymous connection

# %% [markdown]
# ##### Built-In

# %% [markdown]
# - username/password login method
# - usersname are case sensitive

# %% [markdown]
# ```python
# gis = GIS(username='fakeaccount', password='fakepassword')
# gis = GIS(url="https://www.mysite.com/portal", username='fakeaccount', password='fakepassword')
# ```

# %% [markdown]
# **Protecting Built-In Credentials**
#
# - using `profiles` will help protect username and passwords.
# - prevents accidental sharing

# %% [markdown]
# 1. Create a `GIS` object with the extra `profile` parameter
#
# ```python
# gis = GIS(url="https://www.mysite.com/portal",
#           username='fakeaccount',
#           password='fakepassword',
#           profile='portal_profile')
# ```
#
# 2. Now connect using the `profile`
#
# ```python
# gis = GIS(profile='portal_profile')
# ```
#
# **What Happened?**
#
# Instead of keeping your password in plain text, now we leverage the operating system's credential store for the logged in user.  The credentials never get passed on when you use profiles.

# %% [markdown]
# ##### Other Login Methods

# %% [markdown]
# - LDAP
# - IWA
# - PKI
# - OAuth 2.0.
# - API Key
# - Developer Keys (Supported in ArcGIS Online and New at 11.5)

# %% [markdown]
# ### Demo: Developer API Key
#
# <img src="./img/developer_api_key.JPG"/>
#
# - API key authentication is a type of authentication that uses long-lived access tokens embedded directly into an application to authenticate requests to access secure ArcGIS services and items.
#
# You can use API key authentication to:
#
# - Create public applications that do not require users to sign in.
# - Build applications that access location services and items such as hosted layers and data services.
# - Create personal automation scripts that access the portal service and spatial analysis services.
# - Quickly and easily generate access tokens.
# - Embed an access token directly into apps that remains valid for up to 1 year.
# - Access secure resources with the privileges of your ArcGIS account.

# %%
import sys
sys.path.insert(0, r"C:\SVN\geosaurus_master\src")
from arcgis.gis import GIS, ItemProperties, ItemTypeEnum
import datetime as _dt

gis = GIS(profile='your_online_profile', verify_cert=False, trust_env=True)
# Out:
# Setting `verify_cert` to False is a security risk, use at your own risk.

# %%
folder = gis.content.folders.get()
expiration = _dt.datetime(2025, 12, 31, 23, 59, 59)
item_properties:dict = {
    "typeKeywords" : [],
    "type" :"Application",
    "title" :"My First Developer Token",
    "subscriptionType":"app",
    "isPersonalAPIToken":True,
}
item = folder.add(item_properties=item_properties).result()
item
# Out:
# Creating an empty item.
# <Item title:"My First Developer Token" type:Application owner:andrew57>

# %% [markdown]
# #### Register the Application and Define the Privileges

# %%
privileges = ["premium:user:basemaps","premium:user:geocode","premium:user:networkanalysis","premium:user:geoenrichment","portal:user:viewOrgUsers",
              "portal:user:createGroup","portal:user:joinGroup","portal:user:joinNonOrgGroup","portal:user:viewOrgGroups",
              "portal:user:invitePartneredCollaborationMembers","portal:user:addExternalMembersToGroup","portal:user:createItem",
              "portal:publisher:publishFeatures","portal:publisher:publishTiles","portal:publisher:publishScenes",
              "portal:publisher:publishTiledImagery","portal:publisher:publishDynamicImagery","portal:user:viewOrgItems",
              "premium:publisher:createNotebooks","premium:publisher:scheduleNotebooks","portal:user:viewTracks",
              "portal:user:reassignItems","portal:publisher:createDataPipelines","portal:user:shareToGroup","portal:user:shareToOrg","portal:user:shareToPublic",
              "portal:user:shareGroupToOrg","portal:user:shareGroupToPublic","premium:publisher:createAdvancedNotebooks",
              "premium:user:demographics","premium:user:featurereport","features:user:edit","features:user:fullEdit",
              "premium:user:spatialanalysis","premium:publisher:rasteranalysis","portal:admin:viewUsers","portal:admin:updateUsers",
              "portal:admin:deleteUsers","portal:admin:inviteUsers","portal:admin:disableUsers","portal:admin:changeUserRoles",
              "portal:admin:manageLicenses","portal:admin:updateMemberCategorySchema","portal:admin:viewGroups","portal:admin:updateGroups",
              "portal:admin:deleteGroups","portal:admin:reassignGroups","portal:admin:assignToGroups","portal:admin:manageEnterpriseGroups",
              "portal:admin:createUpdateCapableGroup","portal:admin:createLeavingDisallowedGroup","portal:admin:viewItems",
              "portal:admin:updateItems","portal:admin:deleteItems","portal:admin:reassignItems","portal:admin:updateItemCategorySchema",
              "portal:publisher:publishServerGPServices","portal:admin:shareToOrg","portal:admin:shareToPublic","portal:admin:createReports",
              "portal:admin:manageSecurity","portal:admin:manageWebsite","portal:admin:manageCollaborations","portal:admin:manageCredits",
              "portal:admin:manageRoles","portal:admin:manageUtilityServices"]
registration_app_info = item.register(app_type='multiple', redirect_uris=["urn:ietf:wg:oauth:2.0:oob"], http_referers=['http'], privileges=privileges, personal_token=True)
registration_app_info
# Out:
# {'itemId': 'ae9f35ef7f464adda22cf099384deda7',
#  'client_id': 'x8Nu9xujoQnnTqOT',
#  'client_secret': '84928e61efe047efbdaabc56d31d1fd7',
#  'appType': 'multiple',
#  'redirect_uris': ['urn:ietf:wg:oauth:2.0:oob'],
#  'registered': 1741267501000,
#  'modified': 1741267501000,
#  'apnsProdCert': None,
#  'apnsSandboxCert': None,
#  'gcmApiKey': None,
#  'httpReferrers': ['http'],
#  'privileges': ['portal:admin:createUpdateCapableGroup',
#   'portal:user:createItem',
#   'portal:user:viewOrgGroups',
#   'portal:user:joinNonOrgGroup',
#   'premium:publisher:rasteranalysis',
#   'portal:admin:reassignItems',
#   'portal:admin:updateItems',
#   'premium:publisher:createNotebooks',
#   'portal:publisher:publishTiles',
#   'portal:user:shareGroupToPublic',
#   'portal:user:viewOrgUsers',
#   'portal:admin:manageCollaborations',
#   'premium:publisher:createAdvancedNotebooks',
#   'premium:publisher:scheduleNotebooks',
#   'portal:admin:deleteItems',
#   'portal:admin:manageCredits',
#   'portal:user:addExternalMembersToGroup',
#   'portal:admin:disableUsers',
#   'premium:user:geocode',
#   'portal:admin:inviteUsers',
#   'portal:admin:reassignGroups',
#   'portal:admin:changeUserRoles',
#   'portal:user:shareToOrg',
#   'portal:user:shareToPublic',
#   'portal:admin:manageEnterpriseGroups',
#   'portal:admin:manageRoles',
#   'portal:user:invitePartneredCollaborationMembers',
#   'portal:publisher:publishDynamicImagery',
#   'portal:user:viewOrgItems',
#   'portal:admin:assignToGroups',
#   'premium:user:basemaps',
#   'premium:user:demographics',
#   'premium:user:networkanalysis',
#   'portal:user:viewTracks',
#   'portal:admin:manageSecurity',
#   'portal:user:shareToGroup',
#   'portal:admin:createLeavingDisallowedGroup',
#   'portal:admin:createReports',
#   'premium:user:featurereport',
#   'portal:publisher:publishTiledImagery',
#   'portal:admin:deleteUsers',
#   'portal:admin:shareToPublic',
#   'portal:user:createGroup',
#   'features:user:fullEdit',
#   'portal:admin:viewItems',
#   'portal:user:reassignItems',
#   'portal:user:shareGroupToOrg',
#   'premium:user:spatialanalysis',
#   'portal:admin:manageLicenses',
#   'portal:admin:viewGroups',
#   'portal:admin:deleteGroups',
#   'portal:admin:updateUsers',
#   'portal:publisher:publishFeatures',
#   'portal:user:joinGroup',
#   'portal:admin:manageUtilityServices',
#   'portal:admin:updateMemberCategorySchema',
#   'portal:publisher:publishServerGPServices',
#   'portal:admin:viewUsers',
#   'portal:admin:manageWebsite',
#   'portal:publisher:publishScenes',
#   'features:user:edit',
#   'premium:user:geoenrichment',
#   'portal:admin:updateItemCategorySchema',
#   'portal:admin:shareToOrg',
#   'portal:publisher:createDataPipelines',
#   'portal:admin:updateGroups'],
#  'isBeta': False,
#  'isPersonalAPIToken': True,
#  'customAppLoginShowTriage': False}

# %% [markdown]
# ### Generate the Token

# %%
token_info: dict = item.generate_api_token(
    slot=1,
    regenerate=False,
    expiration=_dt.datetime.now() + _dt.timedelta(weeks=30),
)
token_info.keys()
# Out:
# dict_keys(['access_token', 'expires_in'])

# %% [markdown]
# #### Test the Token Out

# %%
print(
    GIS(
        url=gis.resturl,
        token=token_info['access_token'],
        set_active=False,
        verify_cert=False,
        trust_env=True,
    ).properties['appInfo']
)
# Out:
# Setting `verify_cert` to False is a security risk, use at your own risk.
# {'appId': 'x8Nu9xujoQnnTqOT', 'itemId': 'ae9f35ef7f464adda22cf099384deda7', 'appOwner': 'andrew57', 'orgId': 'JEwYeAy2cc8qOe3o', 'appTitle': 'My First Developer Token', 'privileges': ['features:user:edit', 'features:user:editIndoorsSpaces', 'features:user:fullEdit', 'portal:admin:assignToGroups', 'portal:admin:changeUserRoles', 'portal:admin:createLeavingDisallowedGroup', 'portal:admin:createReports', 'portal:admin:createUpdateCapableGroup', 'portal:admin:deleteGroups', 'portal:admin:deleteItems', 'portal:admin:deleteUsers', 'portal:admin:disableUsers', 'portal:admin:inviteUsers', 'portal:admin:manageCollaborations', 'portal:admin:manageCredits', 'portal:admin:manageEnterpriseGroups', 'portal:admin:manageLicenses', 'portal:admin:manageRoles', 'portal:admin:manageSecurity', 'portal:admin:manageUtilityServices', 'portal:admin:manageWebsite', 'portal:admin:reassignGroups', 'portal:admin:reassignItems', 'portal:admin:shareToOrg', 'portal:admin:shareToPublic', 'portal:admin:updateGroups', 'portal:admin:updateItemCategorySchema', 'portal:admin:updateItems', 'portal:admin:updateMemberCategorySchema', 'portal:admin:updateUsers', 'portal:admin:viewGroups', 'portal:admin:viewItems', 'portal:admin:viewUsers', 'portal:publisher:createDataPipelines', 'portal:publisher:publishDynamicImagery', 'portal:publisher:publishFeatures', 'portal:publisher:publishScenes', 'portal:publisher:publishServerGPServices', 'portal:publisher:publishTiledImagery', 'portal:publisher:publishTiles', 'portal:user:addExternalMembersToGroup', 'portal:user:createGroup', 'portal:user:createItem', 'portal:user:invitePartneredCollaborationMembers', 'portal:user:joinGroup', 'portal:user:joinNonOrgGroup', 'portal:user:reassignItems', 'portal:user:shareGroupToOrg', 'portal:user:shareGroupToPublic', 'portal:user:shareToGroup', 'portal:user:shareToOrg', 'portal:user:shareToPublic', 'portal:user:viewOrgGroups', 'portal:user:viewOrgItems', 'portal:user:viewOrgUsers', 'portal:user:viewTracks', 'premium:publisher:createAdvancedNotebooks', 'premium:publisher:createNotebooks', 'premium:publisher:rasteranalysis', 'premium:publisher:scheduleNotebooks', 'premium:user:basemaps', 'premium:user:demographics', 'premium:user:featurereport', 'premium:user:geocode', 'premium:user:geocode:stored', 'premium:user:geocode:temporary', 'premium:user:geoenrichment', 'premium:user:networkanalysis', 'premium:user:networkanalysis:closestfacility', 'premium:user:networkanalysis:lastmiledelivery', 'premium:user:networkanalysis:locationallocation', 'premium:user:networkanalysis:optimizedrouting', 'premium:user:networkanalysis:origindestinationcostmatrix', 'premium:user:networkanalysis:routing', 'premium:user:networkanalysis:servicearea', 'premium:user:networkanalysis:vehiclerouting', 'premium:user:spatialanalysis'], 'expirationDate': 1759407870326}

# %%
item.delete(permanent=True)
# Out:
# True

# %% [markdown]
# # Administering Enterprise

# %%
gis =GIS(profile='your_enterprise_profile')
admin = gis.admin

# %% [markdown]
# ### About Enterprise Administration
#
# The enterprise administration is obtained off of the `GIS.admin` property.
# This property allows administrators to do the following:
#
# - Modify the UX
# - Place the Enterprise into Read Only Mode
# - Security (setting up IWA/Kerberos)
# - Resource File Management
# - Server Management
# - Content Monitoring
# - Log management and querying
# - License management
# - Webhook management
#
# and much more...

# %% [markdown]
# ### Examining All Content
#
# The `admin.content` allows administrators to walk all the Items on an organization.
#
# - Administrators can filter by `item_type`
# - Creates a generator object
# - highly memory effecient

# %%
from arcgis.gis import ItemTypeEnum
for content in admin.content(ItemTypeEnum.FILE_GEODATABASE):
    print(content)
    break
# Out:
# <Item title:"Ports in the Western US" type:File Geodatabase owner:arcgis_python>

# %% [markdown]
# #### Working with Webhooks

# %%
admin.webhooks.list()
# Out:
# []

# %%
# https://webhook.site/#!/view/37973b83-dc8f-43d2-b701-0f19732e0286
admin.webhooks.create(url="https://webhook.site/37973b83-dc8f-43d2-b701-0f19732e0286", name="test webhook")
# Out:
# <WebHook @ test webhook>

# %%
folder = gis.content.folders.get()
sitem = folder.add(item_properties={"title":"test webhook item", 
                                    "type" :"Shapefile"}, 
                   file=r"C:\GIS\cities_webhooks.zip").result()
sitem.delete()

# %% [markdown]
# ##### Web Hook Responses
#
# ##### Adding an Item
# <img src="./img/webhook_add_item_resp.jpg" width=500/>
#
# ##### Deleting an Item
#
# <img src="./img/webhook_delete_item_resp.jpg" width=500/>

# %%
admin.webhooks.list()[0].delete()
# Out:
# True

# %% [markdown]
# ### Working with Enterprise Logs
#
# - When you have a problem, you go to the logs and figure out what went wrong.
# - The logs many issues with your Portal and new at 11.5, it will gather all the enterprise servers as well.
# - Max Age is 90 days.

# %%
admin.logs.properties
# Out:
# {
#   "resources": [
#     "settings"
#   ],
#   "operations": [
#     "query",
#     "clean"
#   ]
# }

# %%
admin.logs.query(start_time=_dt.datetime(2025, 1, 1), 
                 end_time=_dt.datetime(2025, 1, 31), 
                 level='WARNING')
# Out:
# {'hasMore': False,
#  'startTime': 1738262862628,
#  'endTime': 1735714973128,
#  'logMessages': [{'type': 'WARNING',
#    'message': 'The ArcGIS Enterprise deployment has not been backed up since it was created. Strongly consider backing up the deployment using the WebGIS DR tool available within the tools directory.',
#    'time': 1738262862628,
#    'source': 'Portal',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 2180343,
#    'elapsed': '',
#    'process': '1381981',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: Invalid username or password specified for 'ArcGISPyAPIBot'.",
#    'time': 1738261626709,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204051,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: Invalid username or password specified for 'ArcGISPyAPIBot'.",
#    'time': 1738261593397,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204051,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: Invalid username or password specified for 'jroebuck'.",
#    'time': 1738261584616,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204051,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: User 'arcgispyapibot' account has been disabled by your organization.",
#    'time': 1738244418182,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204053,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: User 'arcgispyapibot' account has been disabled by your organization.",
#    'time': 1738244417708,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204053,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: User 'arcgispyapibot' account has been disabled by your organization.",
#    'time': 1738244416980,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204053,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: User 'arcgispyapibot' account has been disabled by your organization.",
#    'time': 1738244416510,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204053,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: User 'arcgispyapibot' account has been disabled by your organization.",
#    'time': 1738231494997,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204053,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: User 'arcgispyapibot' account has been disabled by your organization.",
#    'time': 1738231494578,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204053,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: User 'arcgispyapibot' account has been disabled by your organization.",
#    'time': 1738231493950,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204053,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: User 'arcgispyapibot' account has been disabled by your organization.",
#    'time': 1738231493527,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204053,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: User 'arcgispyapibot' account has been disabled by your organization.",
#    'time': 1738225851314,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204053,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: User 'arcgispyapibot' account has been disabled by your organization.",
#    'time': 1738225850888,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204053,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: User 'arcgispyapibot' account has been disabled by your organization.",
#    'time': 1738225850261,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204053,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: User 'arcgispyapibot' account has been disabled by your organization.",
#    'time': 1738225849835,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204053,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: Invalid username or password specified for 'esri_requests'.",
#    'time': 1738220170960,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204051,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: Invalid username or password specified for 'FakeAccountDNE'.",
#    'time': 1738220170247,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204051,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: Invalid username or password specified for 'esri_requests'.",
#    'time': 1738220169540,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204051,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: Invalid username or password specified for 'dibeltranh_UNCMRH'.",
#    'time': 1738192626012,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204051,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: Invalid username or password specified for 'dibeltranh_UNCMRH'.",
#    'time': 1738192609311,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204051,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: Invalid username or password specified for 'dibeltranh_UNCMRH'.",
#    'time': 1738192586081,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204051,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: Invalid username or password specified for 'dibeltranh'.",
#    'time': 1738192571374,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204051,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: Invalid username or password specified for 'dibeltranh'.",
#    'time': 1738192559143,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204051,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': 'The ArcGIS Enterprise deployment has not been backed up since it was created. Strongly consider backing up the deployment using the WebGIS DR tool available within the tools directory.',
#    'time': 1738176462628,
#    'source': 'Portal',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 2180343,
#    'elapsed': '',
#    'process': '1381981',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Publish error for item 'USA_counties_divorce_rate.tpk'. Service name 'USA_counties_divorce_rate' already exists.",
#    'time': 1738175327799,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': 'jyaist',
#    'code': 200014,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: Invalid username or password specified for 'ehtelAppSupport'.",
#    'time': 1738175170537,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204051,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: Invalid username or password specified for 'ehtelAppSupport'.",
#    'time': 1738175169407,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204051,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: Invalid username or password specified for 'esri_requests'.",
#    'time': 1738162200953,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204051,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: Invalid username or password specified for 'FakeAccountDNE'.",
#    'time': 1738162200187,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204051,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: Invalid username or password specified for 'esri_requests'.",
#    'time': 1738162199437,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204051,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: Invalid username or password specified for 'esri_requests'.",
#    'time': 1738162025979,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204051,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: Invalid username or password specified for 'FakeAccountDNE'.",
#    'time': 1738162025282,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204051,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: Invalid username or password specified for 'esri_requests'.",
#    'time': 1738162024578,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204051,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: User 'arcgispyapibot' account has been disabled by your organization.",
#    'time': 1738143218209,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204053,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: User 'arcgispyapibot' account has been disabled by your organization.",
#    'time': 1738143217719,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204053,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: User 'arcgispyapibot' account has been disabled by your organization.",
#    'time': 1738143217006,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204053,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: User 'arcgispyapibot' account has been disabled by your organization.",
#    'time': 1738143216518,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204053,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: User 'arcgispyapibot' account has been disabled by your organization.",
#    'time': 1738140907302,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204053,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: User 'arcgispyapibot' account has been disabled by your organization.",
#    'time': 1738140906880,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204053,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: User 'arcgispyapibot' account has been disabled by your organization.",
#    'time': 1738140906243,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204053,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: User 'arcgispyapibot' account has been disabled by your organization.",
#    'time': 1738140905820,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204053,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: User 'arcgispyapibot' account has been disabled by your organization.",
#    'time': 1738139451690,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204053,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: User 'arcgispyapibot' account has been disabled by your organization.",
#    'time': 1738139451263,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204053,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: User 'arcgispyapibot' account has been disabled by your organization.",
#    'time': 1738139450621,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204053,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: User 'arcgispyapibot' account has been disabled by your organization.",
#    'time': 1738139450195,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204053,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: Invalid username or password specified for 'esri_requests'.",
#    'time': 1738133665283,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204051,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: Invalid username or password specified for 'FakeAccountDNE'.",
#    'time': 1738133664580,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204051,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: Invalid username or password specified for 'esri_requests'.",
#    'time': 1738133663866,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204051,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: Invalid username or password specified for 'CoGC_PUBLISHER'.",
#    'time': 1738120277788,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204051,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: Invalid username or password specified for 'ehtelAppSupport'.",
#    'time': 1738096369605,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204051,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: Invalid username or password specified for 'ehtelAppSupport'.",
#    'time': 1738096368239,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204051,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': 'The ArcGIS Enterprise deployment has not been backed up since it was created. Strongly consider backing up the deployment using the WebGIS DR tool available within the tools directory.',
#    'time': 1738090062628,
#    'source': 'Portal',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 2180343,
#    'elapsed': '',
#    'process': '1381981',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: Invalid username or password specified for 'esri_requests'.",
#    'time': 1738089415581,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204051,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: Invalid username or password specified for 'FakeAccountDNE'.",
#    'time': 1738089414876,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204051,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: Invalid username or password specified for 'esri_requests'.",
#    'time': 1738089414174,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204051,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: Invalid username or password specified for 'glang'.",
#    'time': 1738084819322,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204051,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: Invalid username or password specified for 'joe.ellis@vidrovr.com'.",
#    'time': 1738072954664,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204051,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: Invalid username or password specified for 'joe.ellis@vidrovr.com'.",
#    'time': 1738072954051,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204051,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: User 'arcgispyapibot' account has been disabled by your organization.",
#    'time': 1738057025731,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204053,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: User 'arcgispyapibot' account has been disabled by your organization.",
#    'time': 1738057025260,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204053,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: User 'arcgispyapibot' account has been disabled by your organization.",
#    'time': 1738057024073,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204053,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: User 'arcgispyapibot' account has been disabled by your organization.",
#    'time': 1738057024555,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204053,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: User 'arcgispyapibot' account has been disabled by your organization.",
#    'time': 1738054578257,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204053,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: User 'arcgispyapibot' account has been disabled by your organization.",
#    'time': 1738054577828,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204053,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: User 'arcgispyapibot' account has been disabled by your organization.",
#    'time': 1738054577196,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204053,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: User 'arcgispyapibot' account has been disabled by your organization.",
#    'time': 1738054576766,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204053,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: User 'arcgispyapibot' account has been disabled by your organization.",
#    'time': 1738053013056,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204053,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: User 'arcgispyapibot' account has been disabled by your organization.",
#    'time': 1738053013485,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204053,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: User 'arcgispyapibot' account has been disabled by your organization.",
#    'time': 1738053012006,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204053,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: User 'arcgispyapibot' account has been disabled by your organization.",
#    'time': 1738053012428,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204053,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: Invalid username or password specified for 'esri_requests'.",
#    'time': 1738047299330,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204051,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: Invalid username or password specified for 'FakeAccountDNE'.",
#    'time': 1738047298615,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204051,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: Invalid username or password specified for 'esri_requests'.",
#    'time': 1738047297899,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204051,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Too many invalid login attempts for user 'joe.ellis@vidrovr.com'.",
#    'time': 1738005039731,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204049,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Too many invalid login attempts for user 'joe.ellis@vidrovr.com'.",
#    'time': 1738005039377,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204049,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: Invalid username or password specified for 'joe.ellis@vidrovr.com'.",
#    'time': 1738005038844,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204051,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: Invalid username or password specified for 'joe.ellis@vidrovr.com'.",
#    'time': 1738004149685,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204051,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: Invalid username or password specified for 'joe.ellis@vidrovr.com'.",
#    'time': 1738004149167,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204051,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: Invalid username or password specified for 'joe.ellis@vidrovr.com'.",
#    'time': 1738003773699,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204051,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: Invalid username or password specified for 'joe.ellis@vidrovr.com'.",
#    'time': 1738003773150,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204051,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: Invalid username or password specified for 'arcgis_python'.",
#    'time': 1738003758761,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204051,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: Invalid username or password specified for 'arcgis_python'.",
#    'time': 1738003758228,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204051,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': 'The ArcGIS Enterprise deployment has not been backed up since it was created. Strongly consider backing up the deployment using the WebGIS DR tool available within the tools directory.',
#    'time': 1738003662628,
#    'source': 'Portal',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 2180343,
#    'elapsed': '',
#    'process': '1381981',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: Invalid username or password specified for 'esri_requests'.",
#    'time': 1737997557965,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204051,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: Invalid username or password specified for 'FakeAccountDNE'.",
#    'time': 1737997557256,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204051,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: Invalid username or password specified for 'esri_requests'.",
#    'time': 1737997556567,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204051,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: Invalid username or password specified for 'kiki_99'.",
#    'time': 1737980832333,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204051,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: Invalid username or password specified for 'kiki_99'.",
#    'time': 1737980827043,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204051,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: Invalid username or password specified for 'esri_requests'.",
#    'time': 1737960881267,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204051,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: Invalid username or password specified for 'FakeAccountDNE'.",
#    'time': 1737960880572,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204051,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: Invalid username or password specified for 'esri_requests'.",
#    'time': 1737960879871,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204051,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: Invalid username or password specified for 'kiki_99'.",
#    'time': 1737940942850,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204051,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': 'The ArcGIS Enterprise deployment has not been backed up since it was created. Strongly consider backing up the deployment using the WebGIS DR tool available within the tools directory.',
#    'time': 1737917262628,
#    'source': 'Portal',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 2180343,
#    'elapsed': '',
#    'process': '1381981',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: Invalid username or password specified for 'esri_requests'.",
#    'time': 1737875723739,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204051,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: Invalid username or password specified for 'FakeAccountDNE'.",
#    'time': 1737875723043,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204051,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: Invalid username or password specified for 'esri_requests'.",
#    'time': 1737875722344,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204051,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': 'The ArcGIS Enterprise deployment has not been backed up since it was created. Strongly consider backing up the deployment using the WebGIS DR tool available within the tools directory.',
#    'time': 1737830862628,
#    'source': 'Portal',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 2180343,
#    'elapsed': '',
#    'process': '1381981',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: Invalid username or password specified for 'esri_requests'.",
#    'time': 1737788113640,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204051,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: Invalid username or password specified for 'FakeAccountDNE'.",
#    'time': 1737788112940,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204051,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: Invalid username or password specified for 'esri_requests'.",
#    'time': 1737788112252,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204051,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': 'The ArcGIS Enterprise deployment has not been backed up since it was created. Strongly consider backing up the deployment using the WebGIS DR tool available within the tools directory.',
#    'time': 1737744462628,
#    'source': 'Portal',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 2180343,
#    'elapsed': '',
#    'process': '1381981',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: Invalid username or password specified for 'geo_ajkum18'.",
#    'time': 1737705931302,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204051,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: Invalid username or password specified for 'gislabajk_123'.",
#    'time': 1737705901720,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204051,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: Invalid username or password specified for 'gislabajk_123'.",
#    'time': 1737705888654,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204051,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: Invalid username or password specified for 'gislabajk_123'.",
#    'time': 1737705879217,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204051,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: Invalid username or password specified for 'esri_requests'.",
#    'time': 1737702112826,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204051,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: Invalid username or password specified for 'FakeAccountDNE'.",
#    'time': 1737702112123,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204051,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': 'The ArcGIS Enterprise deployment has not been backed up since it was created. Strongly consider backing up the deployment using the WebGIS DR tool available within the tools directory.',
#    'time': 1737658062628,
#    'source': 'Portal',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 2180343,
#    'elapsed': '',
#    'process': '1381981',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Publish error for item 'Test_nanae.zip'. Service name '' already exists.",
#    'time': 1737646657097,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': 'naubry',
#    'code': 200014,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: Invalid username or password specified for 'Jack.Daley@arup.com'.",
#    'time': 1737588140826,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204051,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: Invalid username or password specified for 'Jack.Daley@arup.com'.",
#    'time': 1737588135911,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204051,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Too many invalid login attempts for user 'arcgis_python'.",
#    'time': 1737586349789,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204049,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Too many invalid login attempts for user 'arcgis_python'.",
#    'time': 1737586347936,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204049,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Too many invalid login attempts for user 'arcgis_python'.",
#    'time': 1737586345945,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204049,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Too many invalid login attempts for user 'arcgis_python'.",
#    'time': 1737586344134,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204049,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Too many invalid login attempts for user 'arcgis_python'.",
#    'time': 1737585993603,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204049,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Too many invalid login attempts for user 'arcgis_python'.",
#    'time': 1737585992161,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204049,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: Invalid username or password specified for 'arcgis_python'.",
#    'time': 1737585989822,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204051,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: Invalid username or password specified for 'arcgis_python'.",
#    'time': 1737585925499,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204051,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: Invalid username or password specified for 'arcgis_python'.",
#    'time': 1737585923461,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204051,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: Invalid username or password specified for 'arcgis_python'.",
#    'time': 1737585858770,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204051,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: Invalid username or password specified for 'arcgis_python'.",
#    'time': 1737585856440,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204051,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Too many invalid login attempts for user 'arcgis_python'.",
#    'time': 1737585681649,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204049,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Too many invalid login attempts for user 'arcgis_python'.",
#    'time': 1737585680410,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204049,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Too many invalid login attempts for user 'arcgis_python'.",
#    'time': 1737585678505,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204049,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Too many invalid login attempts for user 'arcgis_python'.",
#    'time': 1737585677212,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204049,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Too many invalid login attempts for user 'arcgis_python'.",
#    'time': 1737585543286,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204049,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Too many invalid login attempts for user 'arcgis_python'.",
#    'time': 1737585542027,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204049,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
# ...
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: User 'arcgispyapibot' account has been disabled by your organization.",
#    'time': 1735893887241,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204053,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: User 'arcgispyapibot' account has been disabled by your organization.",
#    'time': 1735893886821,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204053,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: User 'arcgispyapibot' account has been disabled by your organization.",
#    'time': 1735893886195,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204053,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: User 'arcgispyapibot' account has been disabled by your organization.",
#    'time': 1735893885777,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204053,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: Invalid username or password specified for 'FakeAccountDNE'.",
#    'time': 1735887777692,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204051,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': 'The ArcGIS Enterprise deployment has not been backed up since it was created. Strongly consider backing up the deployment using the WebGIS DR tool available within the tools directory.',
#    'time': 1735843662628,
#    'source': 'Portal',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 2180343,
#    'elapsed': '',
#    'process': '1381981',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Too many invalid login attempts for user 'arcgis_python'.",
#    'time': 1735829957065,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204049,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Too many invalid login attempts for user 'arcgis_python'.",
#    'time': 1735829956889,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204049,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: Invalid username or password specified for 'arcgis_python'.",
#    'time': 1735829956668,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204051,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: Invalid username or password specified for 'arcgis_python'.",
#    'time': 1735829927797,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204051,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: Invalid username or password specified for 'arcgis_python'.",
#    'time': 1735829927540,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204051,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: Invalid username or password specified for 'arcgis_python'.",
#    'time': 1735829916071,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204051,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: Invalid username or password specified for 'arcgis_python'.",
#    'time': 1735829915789,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204051,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: User 'arcgispyapibot' account has been disabled by your organization.",
#    'time': 1735817067212,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204053,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: User 'arcgispyapibot' account has been disabled by your organization.",
#    'time': 1735817066789,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204053,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: User 'arcgispyapibot' account has been disabled by your organization.",
#    'time': 1735817066164,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204053,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: User 'arcgispyapibot' account has been disabled by your organization.",
#    'time': 1735817065742,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204053,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: User 'arcgispyapibot' account has been disabled by your organization.",
#    'time': 1735812022109,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204053,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: User 'arcgispyapibot' account has been disabled by your organization.",
#    'time': 1735812021690,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204053,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: User 'arcgispyapibot' account has been disabled by your organization.",
#    'time': 1735812021055,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204053,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: User 'arcgispyapibot' account has been disabled by your organization.",
#    'time': 1735812020636,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204053,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: Invalid username or password specified for 'donggang611'.",
#    'time': 1735810809317,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204051,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: Invalid username or password specified for 'dongg'.",
#    'time': 1735810795731,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204051,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: Invalid username or password specified for 'donggang611'.",
#    'time': 1735810738257,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204051,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: Invalid username or password specified for 'dongg'.",
#    'time': 1735810551156,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204051,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: Invalid username or password specified for 'dongg'.",
#    'time': 1735808862573,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204051,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: Invalid username or password specified for 'dongg'.",
#    'time': 1735808248120,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204051,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: Invalid username or password specified for 'dongg'.",
#    'time': 1735808218009,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204051,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: Invalid username or password specified for 'FakeAccountDNE'.",
#    'time': 1735802091253,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204051,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': 'The ArcGIS Enterprise deployment has not been backed up since it was created. Strongly consider backing up the deployment using the WebGIS DR tool available within the tools directory.',
#    'time': 1735757262628,
#    'source': 'Portal',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 2180343,
#    'elapsed': '',
#    'process': '1381981',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: User 'arcgispyapibot' account has been disabled by your organization.",
#    'time': 1735738845162,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204053,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: User 'arcgispyapibot' account has been disabled by your organization.",
#    'time': 1735738844692,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204053,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: User 'arcgispyapibot' account has been disabled by your organization.",
#    'time': 1735738843986,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204053,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: User 'arcgispyapibot' account has been disabled by your organization.",
#    'time': 1735738843454,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204053,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: User 'arcgispyapibot' account has been disabled by your organization.",
#    'time': 1735726650733,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204053,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: User 'arcgispyapibot' account has been disabled by your organization.",
#    'time': 1735726650317,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204053,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: User 'arcgispyapibot' account has been disabled by your organization.",
#    'time': 1735726649701,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204053,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: User 'arcgispyapibot' account has been disabled by your organization.",
#    'time': 1735726649285,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204053,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: User 'arcgispyapibot' account has been disabled by your organization.",
#    'time': 1735721038326,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204053,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: User 'arcgispyapibot' account has been disabled by your organization.",
#    'time': 1735721037882,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204053,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: User 'arcgispyapibot' account has been disabled by your organization.",
#    'time': 1735721037253,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204053,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: User 'arcgispyapibot' account has been disabled by your organization.",
#    'time': 1735721036830,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204053,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''},
#   {'type': 'WARNING',
#    'message': " Sign in error: Invalid username or password specified for 'FakeAccountDNE'.",
#    'time': 1735714973128,
#    'source': 'Sharing',
#    'machine': 'IP-172-31-37-58.US-EAST-2.COMPUTE.INTERNAL',
#    'user': '',
#    'code': 204051,
#    'elapsed': '',
#    'process': '1382452',
#    'thread': '1',
#    'methodName': '',
#    'requestID': ''}]}

# %% [markdown]
# ### Managing Federated Services
#
# - Provides access to federate and unfederated servers
# - Allows administrators to `list` or `get` servers
# - Allows for validation of Federated servers to check for problems.

# %%
server_mgr = admin.servers
server_mgr
# Out:
# < ServerManager @ https://pythonapi.playground.esri.com/portal/portaladmin >

# %% [markdown]
# ##### Server Validation

# %%
server_mgr.validate()

# %% [markdown]
# ##### Get the Hosting Servers

# %%
hosting_server = server_mgr.get("HOSTING_SERVER")[0]
hosting_server
# Out:
# < Server @ https://pythonapi.playground.esri.com/server/admin >

# %% [markdown]
# ### Managing Enterprise Resources
#
# As administrators, you have access to the under pinnings of the system.  Things like home page settings and other system resources can be managed from the admin endpoint.

# %% [markdown]
# ##### Listing System Resources

# %%
admin.resources.list()
# Out:
# [{'key': 'home.page.json',
#   'size': 780,
#   'created': 1741276370057,
#   'access': 'org'},
#  {'key': 'localizedOrgProperties',
#   'size': 78,
#   'created': 1741276369941,
#   'access': 'org'}]

# %% [markdown]
# #### UI/UX Customization
#
# The ArcGIS API for Python allows users to create, clone and edit the user experience on both ArcGIS Online and Enterprise.

# %%
uxmgr = admin.ux
uxmgr.description, uxmgr.name
# Out:
# ('This is a Demo Enterprise Hosted by the ArcGIS API for Python Team',
#  "ArcGIS API for Python's Demo Enterprise")

# %%
uxmgr.description = 'This is a Demo Enterprise Hosted by the ArcGIS API for Python Team'
uxmgr.name = "ArcGIS API for Python's Demo Enterprise"
uxmgr.description, uxmgr.name
# Out:
# ('This is a Demo Enterprise Hosted by the ArcGIS API for Python Team',
#  "ArcGIS API for Python's Demo Enterprise")

# %%
og_title = uxmgr.homepage_settings.get_title()
og_title['title']
# Out:
# 'ArcGIS API for Python Enterprise'

# %%
uxmgr.homepage_settings.get_background()
# Out:
# 'RIVERVIOLET'

# %% [markdown]
# ##### Current Status of Home Page
#
# <img src="./img/og_ux_part1.jpg" width=50%/>

# %% [markdown]
# #### Modify the UX

# %%
from arcgis.gis.admin import StockImage
uxmgr.homepage_settings.set_background(stock_image=StockImage.GEOLOGYAMBER)
uxmgr.homepage_settings.set_title(title='ArcGIS API for Python Demo Enterprise')
# Out:
# True

# %% [markdown]
# ##### Updated Status of Home Page
#
# <img src="./img/og_ux_part2.jpg" width=50%/>

# %% [markdown]
# #### Cloning the User Interface
#
# Once you have a UI/UX design completed and ready to go, you can `clone` it and save it locally.

# %%
ux_settings = uxmgr.clone()[0].result()
print(ux_settings)
# Out:
# C:\Users\andr5624\AppData\Local\Temp\1\9cfd73\d7e1f.uxpk

# %%
uxmgr.load_offline_configuration(ux_settings)
# Out:
# True

# %%
# reset the values
uxmgr.description = 'This is a Demo Enterprise Hosted by the Python API'
uxmgr.name = 'ArcGIS API for Python Enterprise'
uxmgr.homepage_settings.set_background(stock_image=StockImage.RIVERVIOLET)
# Out:
# True

# %% [markdown]
# #### Read-Only Mode
#
# - Switching an enterprise to read-only mode allows organizations to stop the addition of new information.
# - One use case is in preperation of content migration, an administrator would place the organization into read only mode.

# %%
admin.mode
# Out:
# {'isReadOnly': False}

# %% [markdown]
# ```python
# mode_settings = admin.mode
# mode_settings['isReadOnly'] = True
# admin.mode = mode_settings
# admin.mode
# {'isReadOnly': True}
# ```

# %% [markdown]
# ## Managing Content

# %%
from arcgis.gis import GIS
from arcgis.auth.tools._util import detect_proxy
gis = GIS(profile='your_online_profile', verify_cert=False, proxy=detect_proxy(True))
# Out:
# Setting `verify_cert` to False is a security risk, use at your own risk.

# %%
cm = gis.content
cm

# %% [markdown]
# ### Working with Content

# %% [markdown]
# <img src="./img/content-manager.jpg"/>
#
# **The content manager allows users and administrators to work with, find and manage content**

# %% [markdown]
# #### Searching

# %% [markdown]
# ##### `search` Example

# %% [markdown]
# - provides a simple search method
# - max items is 10,000
# - do not have full control over searches

# %%
cm.search(query="title: battle", item_type="Feature Layer", outside_org=False)
# Out:
# []

# %%
cm.search(query="title: battle", item_type="Feature Layer", outside_org=True)
# Out:
# [<Item title:"Civil_War_Battles" type:Feature Layer Collection owner:t3g09_BarbareeDuke>,
#  <Item title:"Battles won by rebel forces" type:Feature Layer Collection owner:koneill_worldmap>,
#  <Item title:"5kmNearest_Site_Poteniels_to_Battles" type:Feature Layer Collection owner:LroyCWT>,
#  <Item title:"Key US Civil War Battles-Decisive" type:Feature Layer Collection owner:rzhu_nvcc>,
#  <Item title:"Wiltshire Battlefield (polygon)" type:Feature Layer Collection owner:GillyH>,
#  <Item title:"Bad Bird Village_WFL1" type:Feature Layer Collection owner:Steven.Wahweotten_Pokagon>,
#  <Item title:"Cost of Living Index Ian Battles_WFL1" type:Feature Layer Collection owner:battles.i_ENVR>,
#  <Item title:"Battle of Gettysburg Day 1" type:Feature Layer Collection owner:kjohnson@junipercre.com>,
#  <Item title:"Civil War Battles" type:Feature Layer Collection owner:kjohnson@junipercre.com>,
#  <Item title:"TN_Civil_War_Battles" type:Feature Layer Collection owner:GREENMAS>]

# %% [markdown]
# ##### `advanced_search` Example

# %% [markdown]
# - full control searching option
# - removed limitations of `search`
# - returns items as dictionary, which speeds up searches
# - leverage system for simple statistics about content

# %% [markdown]
# **How Many Item to Examine?**

# %%
count = cm.advanced_search('title: battle AND  (type:"feature service")', return_count=True)
count
# Out:
# 642

# %%
items = cm.advanced_search('title: battle AND  (type:"feature service")', max_items=count, 
                           sort_field='avgRating', sort_order='desc')['results']
items[10:20]
# Out:
# [<Item title:"Hot Spots ACLED-Version-5-All-Africa-1997-2014_battles" type:Feature Layer Collection owner:snyongesa_EsriEAsolutions>,
#  <Item title:"WII Battles_ European Theatre Casualty Count_WFL1" type:Feature Layer Collection owner:rrobertson33_cp4510>,
#  <Item title:"HS_USH_IM_T12_L06_001M_view" type:Feature Layer Collection owner:skktracy>,
#  <Item title:"Civil_War_Battles - Battles_1861" type:Feature Layer Collection owner:CP4510Students_gtmaps>,
#  <Item title:"HS_WH_IM_T11_L07_001M_view" type:Feature Layer Collection owner:skktracy>,
#  <Item title:"Military Battle Lines" type:Feature Layer Collection owner:tenglim_worldmap>,
#  <Item title:"Podcasts in Antietam National Battlefield - Explore Natural Communities" type:Feature Layer Collection owner:dhauverb10>,
#  <Item title:"City_of_Battle_Ground_Watersheds" type:Feature Layer Collection owner:CityofBattleGround>,
#  <Item title:"HLL_Battle_App___Deployable_Line_Features_SMdM" type:Feature Layer Collection owner:topher303>,
#  <Item title:"HLL_Battle_App___Front_Lines_Foy" type:Feature Layer Collection owner:topher303>]

# %% [markdown]
# **Gathering Information from Searches**
#
# - In this demo we will see how much new content was added to the organization in the last 5 days.

# %%
import datetime as _dt

now =_dt.datetime.now(_dt.timezone.utc)
then = now - _dt.timedelta(days=5)

# %%
cm.advanced_search(
    f"created: [{int(then.timestamp()* 1000)} TO {int(now.timestamp()* 1000)}] AND accountid:{gis.properties.id}", 
    return_count=True)
# Out:
# 57

# %% [markdown]
# #### Adding and Publishing Content

# %%
import uuid
username = f"UCUser{uuid.uuid4().hex[:3]}"
password = f"!{uuid.uuid4().hex[:6]}A"
user = gis.users.create(username=username,
        password=password,
        firstname=uuid.uuid4().hex[:6],
        lastname=uuid.uuid4().hex[:6],
        email=uuid.uuid4().hex[:6] + "@esri.com",
        role='org_publisher')
user
# Out:
# <User username:UCUser4ec>

# %%
user.items()
# Out:
# []

# %% [markdown]
# ##### Publishing a Table

# %%
import io, uuid
import pandas as pd
from arcgis.gis import ItemProperties, ItemTypeEnum

# %%
buffer = io.StringIO()
df = pd.read_csv("./data/banklist.csv")
df.to_csv(buffer)

# %%
from arcgis.gis import GIS
gis = GIS(profile='your_online_profile')

# %%
item_failed_banks = gis.content.add(
        item_properties={
            "type": "CSV",
            "title": "Failed Banks",
            "fileName": f"failedbanks{uuid.uuid4().hex[:5]}.csv",
        },
        data=buffer,
)

# %%
analyzed = gis.content.analyze(item=item_failed_banks)
publish_parameters = analyzed['publishParameters']
publish_parameters[
        'name'
    ] = f"Failed_Banks_{uuid.uuid4().hex[:2]}"  # this needs to be updated
publish_parameters['locationType'] = None  # this makes it a hosted table
published_item = item_failed_banks.publish(publish_parameters)

# %%
published_item
# Out:
# <Item title:"Failed Banks" type:Table Layer owner:andrew57>

# %% [markdown]
# ##### Adding/Publishing Content to a User

# %%
user_item = gis.content.add(
    item_properties= {'title' : 'World Cities', 
                      'tags' : "cities, world coverage, population", 
                      'type' : "Shapefile" },
    data=r"/data/cities.zip",
    owner=user,
)
user_item
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19232\3291534777.py in <cell line: 1>()
# ----> 1 user_item = gis.content.add(
#       2     item_properties= {'title' : 'World Cities',
#       3                       'tags' : "cities, world coverage, population",
#       4                       'type' : "Shapefile" },
#       5     data=r"/data/cities.zip",
#
# C:\SVN\geosaurus_master\src\arcgis\gis\__init__.py in add(self, item_properties, data, thumbnail, metadata, owner, folder, item_id, **kwargs)
#    6900             if "text" in kwargs:
#    6901                 item_properties["text"] = kwargs.pop("text", None)
# -> 6902             itemid = self._portal.add_item(
#    6903                 item_properties,
#    6904                 data,
#
# C:\SVN\geosaurus_master\src\arcgis\gis\_impl\_portalpy.py in add_item(self, item_properties, data, thumbnail, metadata, owner, folder)
#     396             elif isinstance(data, (io.BytesIO, io.StringIO)) == False:
#     397                 if not os.path.isfile(os.path.abspath(data)):
# --> 398                     raise RuntimeError("File(" + data + ") not found.")
#     399             if isinstance(data, (io.BytesIO, io.StringIO)):
#     400                 fn = item_properties.get("fileName", None)
#
# RuntimeError: File(/data/cities.zip) not found.

# %%
pitem = user_item.publish({'name' : f'world{uuid.uuid4().hex[:4]}cities'})
pitem
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19232\639815056.py in <cell line: 1>()
# ----> 1 pitem = user_item.publish({'name' : f'world{uuid.uuid4().hex[:4]}cities'})
#       2 pitem
#
# NameError: name 'user_item' is not defined

# %% [markdown]
# ##### Reassigning Content

# %%
user.items()

# %%
folder = gis.content.create_folder("uc_demo_migration_folder")
folder

# %%
item = user.items()[-1]
item.reassign_to(target_owner=gis.users.me.username,
    target_folder= 'uc_demo_migration_folder')

# %%
gis.users.me.items("uc_demo_migration_folder")

# %% [markdown]
# ##### Erase the User

# %%
user.delete()
# Out:
# True

# %% [markdown]
# ## Metadata

# %% [markdown]
# - Administrators can enable metadata for the organization

# %%
gis = GIS(profile='your_online_profile')
mm = gis.admin.metadata
mm
# Out:
# < MetadataManager at https://geosaurus.maps.arcgis.com >

# %%
mm.enable()
# Out:
# True

# %%
mm.is_enabled
# Out:
# True

# %% [markdown]
# ## Content Migration/ Monitoring

# %% [markdown]
# ### Cloning Items

# %% [markdown]
# **`clone_items` provides the ability to copy content from one site to another**

# %% [markdown]
# <img src="./img/clone_items.jpg" />

# %% [markdown]
# ## Continue onto Reporting and Monitoring
