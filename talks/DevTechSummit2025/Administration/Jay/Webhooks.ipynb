# %%
import arcgis
gis = arcgis.GIS(profile="your_demo_profile")
gis.users.me
# Out:
# <User username:jroebuck>

# %%
webhooks = gis.admin.webhooks.list()
webhooks
# Out:
# [<WebHook @ Demo-All-Notify-DnsHook>]

# %%
webhook = webhooks[0]
webhook
# Out:
# <WebHook @ Demo-All-Notify-DnsHook>

# %%
webhook.deactivate()
# Out:
# True

# %%
webhook.activate()
# Out:
# True
