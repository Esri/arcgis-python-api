# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Importing, Exporting, Geometry Engines, Oh My!
#
# Now that we've seen the basics of Pandas, NumPy, and the Spatially Enabled DataFrame, let's cover one of the most useful applications of it: reading and writing data. In addition to manipulation and analysis, the Spatially Enabled DataFrame gives you a wide range of options for handling and persisting data. We'll cover the basics of how it works, and some new functionality added in the ArcGIS API for Python version 2.4.1 that gives users even more power in the ways they can read/write.
#
# ### Behind the Scenes
#
# First, let's go over how things work behind the scenes. As I'm sure many of you are familiar with, there are numerous different formats that spatial data can be stored in. The two most common ones are File Geodatabase and Shapefile, which are the ones we'll focus on here. These two formats were both designed by Esri, and went in tandem with or resulted in the development of geometry engines that could process these respective types. Most notably, ArcPy is used for File Geodatabases, and shapely/pyshp for Shapefiles. This meant that prior to 2.4.1, users had to have arcpy in their environment to read/write File Geodatabases, and a Shapefile-specific engine to read and write Shapefile. However, we've brought some changes.
#
# We've worked GDAL into the reading/writing functions behind the scenes, which means that users can now easily translate these data types with one single shape engine. For anybody unfamiliar, GDAL stands for Geospatial Data Abstraction Library, and is an open source library that can read/write a wide variety of raster and vector geospatial data formats. It already comes in the standard environment for ArcGIS Pro on Windows, and can also be installed via Python package managers Conda and Pip on Linux & MacOS. This means that File Geodatabases are now easily read into/written from the SeDF on Linux and Mac. Let's jump in!

# %%
# set the environment variable with os.environ
# very important to do this before importing arcgis! must reset environment otherwise
import os
os.environ["ARCGIS_GEOMETRY_ENGINE"] = "gdal" # 'gdal', 'shapefile', 'arcpy'

# %%
from arcgis.features import GeoAccessor, GeoSeriesAccessor
import pandas as pd

# %%
# these are hidden properties that show us environment info
from arcgis._impl._geometry_engine import SELECTED_ENGINE, HAS_ARCPY, HAS_GDAL, HAS_PYSHP
print("Has ArcPy: " + str(HAS_ARCPY))
print("Has GDAL: " + str(HAS_GDAL))
print("Has PySHP: " + str(HAS_PYSHP))
print("Selected Engine: " + str(SELECTED_ENGINE))
# Out:
# Has ArcPy: True
# Has GDAL: True
# Has PySHP: True
# Selected Engine: GeometryEngine.GDAL

# %% [markdown]
# It's as easy as that! Now that we have our shape engine set, let's look at all the different sources we can import data from.

# %% [markdown]
# #### Shapefile

# %%
# importing from a shapefile on disk
sedf = pd.DataFrame.spatial.from_featureclass(r"C:\Users\computer\Downloads\rewritten_to_shape\rewritten_to_shape.shp")
sedf
# Out:
#   fav_color  fav_number      time  \
# 0     green           7  10:30:23
# 1      blue          10  21:34:20
# 2       red           4  18:04:55
#
#                                                SHAPE
# 0  {"x": 1049942.711199999, "y": 6331440.64400000...
# 1  {"x": 1044536.801399998, "y": 6334525.54599999...
# 2  {"x": 1042749.384300001, "y": 6332430.48569999...

# %% [markdown]
# #### File Geodatabase

# %%
# importing from fgdb on disk
sedf = pd.DataFrame.spatial.from_featureclass(r"C:\Users\computer\Downloads\gdal_to_gdb.gdb")
sedf
# Out:
#   fav_color  fav_number      time  \
# 0     green           7  10:30:23
# 1      blue          10  21:34:20
# 2       red           4  18:04:55
#
#                                                SHAPE
# 0  {"x": 1049942.711199999, "y": 6331440.64400000...
# 1  {"x": 1044536.801399998, "y": 6334525.54599999...
# 2  {"x": 1042749.384300001, "y": 6332430.48569999...

# %% [markdown]
# #### Feature Layer

# %%
# importing from feature layer
from arcgis.gis import GIS
from arcgis.features import FeatureLayer
gis = GIS("Home")
flayer = FeatureLayer("https://services7.arcgis.com/JEwYeAy2cc8qOe3o/arcgis/rest/services/kc_house_data_XYTableToPoint/FeatureServer/0")
sedf = pd.DataFrame.spatial.from_layer(flayer)
sedf
# Out:
#        OBJECTID            id             date     price  bedrooms  bathrooms  \
# 0             1  7129300520.0  20141013T000000  221900.0         3        1.0
# 1             2  6414100192.0  20141209T000000  538000.0         3       2.25
# 2             3  5631500400.0  20150225T000000  180000.0         2        1.0
# 3             4  2487200875.0  20141209T000000  604000.0         4        3.0
# 4             5  1954400510.0  20150218T000000  510000.0         3        2.0
# ...         ...           ...              ...       ...       ...        ...
# 21608     15609  3904100089.0  20150318T000000  300000.0         3       1.75
# 21609     15610  1797500780.0  20140521T000000  540000.0         3        2.0
# 21610     15611  7614100080.0  20150211T000000  140000.0         3       1.75
# 21611     15612    87000006.0  20150413T000000  275000.0         4       1.75
# 21612     15613  8074200185.0  20140825T000000  370000.0         3       2.75
#
#        sqft_living  sqft_lot  floors  waterfront  ...  sqft_above  \
# 0             1180      5650     1.0           0  ...        1180
# 1             2570      7242     2.0           0  ...        2170
# 2              770     10000     1.0           0  ...         770
# 3             1960      5000     1.0           0  ...        1050
# 4             1680      8080     1.0           0  ...        1680
# ...            ...       ...     ...         ...  ...         ...
# 21608         1350      7370     1.0           0  ...        1350
# 21609         1470      1691     2.0           0  ...        1000
# 21610         1270      8991     2.0           0  ...        1270
# 21611         1680     19405     1.0           0  ...        1560
# 21612         2120      7650     1.0           0  ...        2120
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 0                  0      1955             0    98178  47.5112 -122.257
# 1                400      1951          1991    98125   47.721 -122.319
# 2                  0      1933             0    98028  47.7379 -122.233
# 3                910      1965             0    98136  47.5208 -122.393
# 4                  0      1987             0    98074  47.6168 -122.045
# ...              ...       ...           ...      ...      ...      ...
# 21608              0      1912             0    98118  47.5336 -122.278
# 21609            470      2007             0    98115  47.6743 -122.316
# 21610              0      1981             0    98042  47.3563 -122.149
# 21611            120      1959             0    98055  47.4552 -122.202
# 21612              0      1958             0    98056  47.4923 -122.178
#
#        sqft_living15  sqft_lot15  \
# 0               1340        5650
# 1               1690        7639
# 2               2720        8062
# 3               1360        5000
# 4               1800        7503
# ...              ...         ...
# 21608           1440        6000
# 21609           1660        4000
# 21610           1270        8993
# 21611           2000       12900
# 21612           1180        7650
#
#                                                    SHAPE
# 0      {"x": -122.25699999999995, "y": 47.51120000093...
# 1      {"x": -122.31899999999996, "y": 47.72100000093...
# 2      {"x": -122.23299999999996, "y": 47.73790000093...
# 3      {"x": -122.39299999999997, "y": 47.52080000093...
# 4      {"x": -122.04499999999996, "y": 47.61680000093...
# ...                                                  ...
# 21608  {"x": -122.27799999999995, "y": 47.53360000093...
# 21609  {"x": -122.31599999999999, "y": 47.67430000093...
# 21610  {"x": -122.14899999999994, "y": 47.35630000093...
# 21611  {"x": -122.20199999999996, "y": 47.45520000093...
# 21612  {"x": -122.17799999999994, "y": 47.49230000093...
#
# [21613 rows x 23 columns]

# %% [markdown]
# #### URL

# %%
# importing from shapefile at a URL
sedf = pd.DataFrame.spatial.from_featureclass(r"https://www.arcgis.com/sharing/rest/content/items/804abf2794b346828eeff285bffe9259/data")
sedf
# Out:
#     ACTIVITYCO INPUT_DATE  EDIT_DATE  \
# 0         EKHC 2024-10-24 2024-10-24
# 1         EKHC 2024-10-24 2024-10-24
# 2         EKHC 2024-10-24 2024-10-24
# 3         EKHC 2024-10-24 2024-10-24
# 4         EKHC 2024-10-24 2024-10-24
# ..         ...        ...        ...
# 362       EKHC 2024-10-24 2024-10-24
# 363       EKHC 2024-10-24 2024-10-24
# 364       EKHC 2024-10-24 2024-10-24
# 365       EKHC 2024-10-24 2024-10-24
# 366       EKHC 2024-10-24 2024-10-24
#
#                                                  SHAPE
# 0    {"rings": [[[453602.48000000045, 4098028.34999...
# 1    {"rings": [[[336426.4754999997, 4102376.7609],...
# 2    {"rings": [[[503809.86510000005, 4113120.54409...
# 3    {"rings": [[[496311.0599999996, 4112007.26], [...
# 4    {"rings": [[[255773.25, 4117713.369999999], [2...
# ..                                                 ...
# 362  {"rings": [[[319267.9144000001, 4262033.4571],...
# 363  {"rings": [[[337010.0694000004, 4295655.9245],...
# 364  {"rings": [[[337936.74509999994, 4267894.5615]...
# 365  {"rings": [[[354751.16980000027, 4260167.13660...
# 366  {"rings": [[[399369.3995000003, 4198319.068700...
#
# [367 rows x 4 columns]

# %% [markdown]
# #### CSV

# %%
# read a CSV into a dataframe then use from_xy
df = pd.read_csv(r"C:\Users\computer\Downloads\new.csv")
sedf = pd.DataFrame.spatial.from_xy(df, "x", "y")
sedf
# Out:
#     FID  city_id            name state capital  pop2000  pop2007   longitude  \
# 0     1        1        Honolulu    HI   State    37165    37858 -157.823436
# 1     2        2          Juneau    AK   State    30711    31592 -134.511582
# 2     3        3      Boise City    ID   State    18578    20352 -116.237655
# 3     4        4         Olympia    WA   State    27514    45523 -122.893073
# 4     5        5           Salem    OR   State    13692    15203 -123.029155
# 5     6        6          Carson    NV   State    52457    56641 -119.753873
# 6     7        7      Sacramento    CA   State    40701    46291 -121.468927
# 7     8        8         Phoenix    AZ   State    13210    15021 -112.076300
# 8     9        9  Salt Lake City    UT   State    18174    18536 -111.892618
# 9    10       10        Cheyenne    WY   State    53011    54750  104.802046
# 10   11       11          Denver    CO   State    55463    57806 -104.965482
# 11   12       12        Santa Fe    NM   State    62203    68975 -105.964573
# 12   13       13   Oklahoma City   OKK   State    50613    55255  -97.534991
# 13   14       14          Topeka    KS   State    12237    12221  -95.689509
# 14   15       15         Lincoln    NE   State    22558    24382  -96.675346
# 15   16       16      Des Moines    IA   State    20068    20125  -93.620864
# 16   17       17  Jefferson City    MO   State    39636    38718  -92.189282
# 17   18       18     Little Rock    AR   State    18313    19064  -92.331118
# 18   19       19          Austin    TX   State        0        0  -97.747246
#
#      latitude  ObjectId           x          y  \
# 0   21.305782         1 -157.823436  21.305782
# 1   58.351418         2 -134.511582  58.351418
# 2   43.613736         3 -116.237655  43.613736
# 3   47.042418         4 -122.893073  47.042418
# 4   44.931109         5 -123.029155  44.931109
# 5   39.160946         6 -119.753873  39.160946
# 6   38.555609         7 -121.468927  38.555609
# 7   33.528373         8 -112.076300  33.528373
# 8   40.754700         9 -111.892618  40.754700
# 9  -41.145545        10  104.802046 -41.145545
# 10  39.726291        11 -104.965482  39.726291
# 11  35.667227        12 -105.964573  35.667227
# 12  35.482309        13  -97.534991  35.482309
# 13  39.039200        14  -95.689509  39.039200
# 14  40.809864        15  -96.675346  40.809864
# 15  41.590936        16  -93.620864  41.590936
# 16  38.572955        17  -92.189282  38.572955
# 17  34.736009        18  -92.331118  34.736009
# 18  30.300473        19  -97.747246  30.300473
#
#                                                 SHAPE
# 0   {"spatialReference": {"wkid": 4326}, "x": -157...
# 1   {"spatialReference": {"wkid": 4326}, "x": -134...
# 2   {"spatialReference": {"wkid": 4326}, "x": -116...
# 3   {"spatialReference": {"wkid": 4326}, "x": -122...
# 4   {"spatialReference": {"wkid": 4326}, "x": -123...
# 5   {"spatialReference": {"wkid": 4326}, "x": -119...
# 6   {"spatialReference": {"wkid": 4326}, "x": -121...
# 7   {"spatialReference": {"wkid": 4326}, "x": -112...
# 8   {"spatialReference": {"wkid": 4326}, "x": -111...
# 9   {"spatialReference": {"wkid": 4326}, "x": 104....
# 10  {"spatialReference": {"wkid": 4326}, "x": -104...
# 11  {"spatialReference": {"wkid": 4326}, "x": -105...
# 12  {"spatialReference": {"wkid": 4326}, "x": -97....
# 13  {"spatialReference": {"wkid": 4326}, "x": -95....
# 14  {"spatialReference": {"wkid": 4326}, "x": -96....
# 15  {"spatialReference": {"wkid": 4326}, "x": -93....
# 16  {"spatialReference": {"wkid": 4326}, "x": -92....
# 17  {"spatialReference": {"wkid": 4326}, "x": -92....
# 18  {"spatialReference": {"wkid": 4326}, "x": -97....

# %% [markdown]
# ### Writing Out
#
# Now that we have more SeDF's than we know what to do with, let's spam our local disk and GIS org with them in different ways!

# %%
flayer = FeatureLayer("https://services7.arcgis.com/JEwYeAy2cc8qOe3o/arcgis/rest/services/kc_house_data_XYTableToPoint/FeatureServer/0")
sedf = pd.DataFrame.spatial.from_layer(flayer)

# %%
# first let's do to shapefile
sedf.spatial.to_featureclass(r"C:\Users\computer\Downloads\DevSummit\to_shape\out_example.shp")
# Out:
# 'C:\\Users\\noa12726\\Downloads\\DevSummit\\to_shape\\out_example.shp'

# %%
# then let's do to file geodatabase
sedf.spatial.to_featureclass(r"C:\Users\computer\Downloads\DevSummit\to_fgdb\out_example.gdb")
# Out:
# 'C:\\Users\\noa12726\\Downloads\\DevSummit\\to_fgdb\\out_example.gdb\\out_example'

# %%
sedf = pd.DataFrame.spatial.from_featureclass(r"C:\Users\computer\Downloads\rewritten_to_shape\rewritten_to_shape.shp")
new_item = sedf.spatial.to_featurelayer("Dev Summit Example")
new_item
# Out:
# <Item title:"Dev Summit Example" type:Feature Layer Collection owner:nparavicini_geosaurus>
