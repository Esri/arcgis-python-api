# %% [markdown]
# # What's new in version 2.4.4
#
# ## New
# * **New Module:**
#   * [`arcgis.gis.video`](/python/latest/api-reference/arcgis.gis.video.html)
#     * Provides classes, methods and properties for administration capabilities on ArcGIS Video Server
# * **Beta Transtion**
#   * [`arcgis.raster.realitymapping`](/python/latest/api-reference/arcgis.raster.realitymapping.html)
#     * [ArcGIS Reality Server](https://doc.esri.com/en/arcgis-reality-server/latest/introduction/what-is-reality-server.html) product transitioned from **beta** to General Availability
#       * **note:** Scripts written in 2.4.3 may need modified to accommodate necessary API changes based on overall product updates.
#
# ### [Guides](../)
# * **New Subheading:**
#   * [Introduction to gis module](../)
#     * [The gis module](../guide/the-gis-module)
# * [Spatial Analysis](../)
#   * [Raster Analysis](../)
#     * [Reality Mapping](../guide/using-raster-analysis)
#       * [Introduction to Reality Mapping](../guide/introduction-to-reality-mapping/)
#       * [Create 2D Digital Aerial Imagery Products](../guide/create-2D-digital-aerial-products/)
#       * [Create 3D Digital Aerial Imagery Products](../guide/create-3D-digital-aerial-products/)
#       * [Create True Ortho and Digital Surface model from Drone imagery](../guide/create-trueortho-dsm-from-drone-imagery/)
#       * [Create True Ortho and Digital Surface Model Product from Satellite Imagery](../guide/create-trueortho-dsm-from-satellite-imagery/)
# * [AI Capabilities](../)
#   * [Introduction to AI-Powered services](../guide/introduction-to-ai-powered-services/)
# * [Administration](../)
#   * [Managing ArcGIS Applications](../)
#     * [Working with Knowledge Graphs](../)
#       * [Part 4 - Create Replicas and Synchronize Changes](../guide/part4-create-replicas-and-synchronize-changes/)
#
# ### Module Changes
#
# #### [`arcgis.gis`](/python/latest/api-reference/arcgis.gis.toc.html)
# * [`User`](/python/latest/api-reference/arcgis.gis.toc.html#user)
#   * [`reassign_to()`](/python/latest/api-reference/arcgis.gis.toc.html#arcgis.gis.User.reassign_to)
#     * **BUG-000185255** Fixes issue where method inadvertently reassigned *groups* the user was a member of and not just *groups* owned by the user to the *target_username*
#   * [`update()`](/python/latest/api-reference/arcgis.gis.toc.html#arcgis.gis.User.update)
#     * **New Parameters:**
#       * *password*
# * [`UserManager`](/python/latest/api-reference/arcgis.gis.toc.html#usermanager)
#   * **New methods:**
#     * [`all()`](/python/latest/api-reference/arcgis.gis.toc.html#arcgis.gis.UserManager.all)
#       * Adds ability to return all users when total in organization exceeds 10000
#   * [`search()`](/python/latest/api-reference/arcgis.gis.toc.html#arcgis.gis.UserManager)
#     * Updates documentation note to specify number of users returned if no argument entered for *query*
#     * Improves performance with updates to internal caching mechanism
# * [`OfflineContentManager`](/python/latest/api-reference/arcgis.gis.toc.html#OfflineContentManager)
#   * [`export_items()`](/python/latest/api-reference/arcgis.gis.toc.html#arcgis.gis.OfflineContentManager.export_items)
#     * Updates internal logic to better define item structures to enable capability of export of most item types
#     * **New parameters:**
#       * *run_async*
#       * *async_workers*
#   * [`import_content()`](/python/latest/api-reference/arcgis.gis.toc.html#arcgis.gis.OfflineContentManager.import_content)
#     * **New parameters:**
#       * *run_async*
#       * *async_workers*
# * [`Item`](/python/latest/api-reference/arcgis.gis.toc.html#item)
#   * [`publish()`](/python/latest/api-reference/arcgis.gis.toc.html#arcgis.gis.Item.publish)
#     * **BUG-000184773** Improves performance with removal of unnecessary internal processing calls
# * [`SharingManager`](/python/latest/api-reference/arcgis.gis.toc.html#sharingmanager)
#   * [**Public Repo Issue 2335**](https://github.com/Esri/arcgis-python-api/issues/2335) Improves performance with internal processing updates for:
#     * [`shared_with`](/python/latest/api-reference/arcgis.gis.toc.html#arcgis.gis._impl._content_manager.SharingManager.shared_with)
#     * [`sharing_level`](/python/latest/api-reference/arcgis.gis.toc.html#arcgis.gis._impl._content_manager.SharingManager.shared_level)
#   * * [`sharing_level`](/python/latest/api-reference/arcgis.gis.toc.html#arcgis.gis._impl._content_manager.SharingManager.shared_level)
#     * Adds security protection to prevent sharing Datastore items publicly
# * [`ItemProperties`](/python/latest/api-reference/arcgis.gis.toc.html#arcgis.gis._impl._dataclasses.ItemProperties)
#   * Updates to internal processing for more accurate conversion between data objects and reading of object values
# * [`ItemTypeEnum`](/python/latest/api-reference/arcgis.gis.toc.html#itemtypeenum)
#   * Deprecates the *TILES_PACKAGE_3D* member in favor of new options
#   * **New Members:**
#     * *TILES_PACKAGE_3D_GAUSSIAN*
#     * *TILES_PACKAGE_3D_OBJECT*
#     * *TILES_PACKAGE_3D_MESH*
# * [`PortalDataStore`](/python/latest/api-reference/arcgis.gis.toc.html#arcgis.gis._impl._datastores.PortalDataStore)
#   * [`publish()`](/python/latest/api-reference/arcgis.gis.toc.html#arcgis.gis._impl._datastores.PortalDataStore.publish)
#     * **New Parameters:**
#       * *item_id*
#
# #### [`arcgis.gis.admin`](/python/latest/api-reference/arcgis.gis.admin.html#)
# * Updates internal processing of how _admin_ property is assessed for users to better provide correct access for custom roles
# * [`MapSettings`](/python/latest/api-reference/arcgis.gis.admin.html#mapsettings)
#   * [`web_styles()`](/python/latest/api-reference/arcgis.gis.admin.html#arcgis.gis.admin.MapSettings.web_styles)
#     * **New Parameters:**
#       * **ENH-000183856** *two_dimensional_sketch_map*
# * [`SecuritySettings`](/python/latest/api-reference/arcgis.gis.admin.html#securitysettings)
#   * **New Methods:**
#     * [`set_app_signin_settings()`](/python/latest/api-reference/arcgis.gis.admin.html#arcgis.gis.admin.SecuritySettings.set_app_signin_settings)
#   * **New Properties:**
#     * [`approved_apps`](/python/latest/api-reference/arcgis.gis.admin.html#arcgis.gis.admin.SecuritySettings.approved_apps)
#   * Deprecates the following methods and scheduled removal from next release:
#     * [`set_approved_apps()`](/python/latest/api-reference/arcgis.gis.admin.html#arcgis.gis.admin.SecuritySettings.set_approved_apps)
#     * [`set_blocked_apps()`](/python/latest/api-reference/arcgis.gis.admin.html#arcgis.gis.admin.SecuritySettings.set_blocked_apps)
#   * [`set_anonymous_access_notice()`](/python/latest/api-reference/arcgis.gis.admin.html#arcgis.gis.admin.SecuritySettings.set_anonymous_access_notice)
#     * **New Parameters:**
#       * *enabled*
# * [`DeveloperCredential`](/python/latest/api-reference/arcgis.gis.admin.html#developercredential)
#   * Updates reference documentation
#
# #### [`arcgis.gis.agonb`](/python/latest/api-reference/arcgis.gis.agonb.html)
# * Adds numerous code examples to various Class initializers and methods
# * Adds documentation for:
#   * [`Container`](/python/latest/api-reference/arcgis.gis.agonb.html#container)
#   * [`AGORuntime`](/python/latest/api-reference/arcgis.gis.agonb.html#agoruntime)
#   * [`SnapShot`](/python/latest/api-reference/arcgis.gis.agonb.html#snapshot)
# * [`InstancePreference`](/python/latest/api-reference/arcgis.gis.agonb.html#instancepreference)
#   * Deprecates class and schedules for removal at the next release
# * [`AGOLNotebookManager`](/python/latest/api-reference/arcgis.gis.agonb.html#agolnotebookmanager)
#   * [`instance_preferences`](/python/latest/api-reference/arcgis.gis.agonb.html#arcgis.gis.agonb.AGOLNotebookManager.instance_preferences)
#     * Deprecates property and schedules removal at the next release
# * [`ContainerManager()`](/python/latest/api-reference/arcgis.gis.agonb.html#arcgis.gis.agonb.ContainerManager)
#   * [`list()`](/python/latest/api-reference/arcgis.gis.agonb.html#arcgis.gis.agonb.ContainerManager.list)
#     * **New Parameters:**
#       * *as_dict*
#
# #### [`arcgis.gis.nb`](/python/latest/api-reference/arcgis.gis.nb.html)
# * Updates to numerous areas of the API Reference documentation, including code examples
#
# #### [`arcgis.gis.workflowmanager`](/python/latest/api-reference/arcgis.gis.workflowmanager.html)
# * [`WorkflowManagerAdmin`](/python/latest/api-reference/arcgis.gis.workflowmanager.html#workflowmanageradmin)
#  * **New Methods:**
#    * [`webhook_connection()`](/python/latest/api-reference/arcgis.gis.workflowmanager.html#arcgis.gis.workflowmanager.WorkflowManager.webhook_connection)
#    * [`create_webhook_connection()`](/python/latest/api-reference/arcgis.gis.workflowmanager.html#arcgis.gis.workflowmanager.WorkflowManager.create_webhook_connection)
#    * [`update_webhook_connection()`](/python/latest/api-reference/arcgis.gis.workflowmanager.html#arcgis.gis.workflowmanager.WorkflowManager.update_webhook_connection)
#    * [`delete_webhook_connection()`](/python/latest/api-reference/arcgis.gis.workflowmanager.html#arcgis.gis.workflowmanager.WorkflowManager.delete_webhook_connection)
#  * **New Properties:**
#    * [`webhook_connections`](/python/latest/api-reference/arcgis.gis.workflowmanager.html#arcgis.gis.workflowmanager.WorkflowManager.webhook_connections)
#   * Improves performance by adding asynchronous processing to internal functions:
#     * [`create_item()`](/python/latest/api-reference/arcgis.gis.workflowmanager.html#arcgis.gis.workflowmanager.WorkflowManagerAdmin.create_item)
#     * [`upgrade_item()`](/python/latest/api-reference/arcgis.gis.workflowmanager.html#arcgis.gis.workflowmanager.WorkflowManagerAdmin.upgrade_item)
# * [`Job_Manager`](/python/latest/api-reference/arcgis.gis.workflowmanager.html#jobmanager)
#   * [`create()`](/python/latest/api-reference/arcgis.gis.workflowmanager.html#arcgis.gis.workflowmanager.JobManager.create)
#     * Updates *extended_properties* parameter documentation to specific argument as dictionary or list of dictionaries
#
# #### [`arcgis.gis.video`](/python/latest/api-reference/arcgis.gis.video.html)
# ** New Submodule **
#   * Provides administrative capabilities for ArcGIS Video Server sites. See [Work with ArcGIS Video Server administrator options](https://doc.esri.com/en/arcgis-video-server/latest/install/admin-operations.html?pivots=os-windows) for information on what API can help automate.
#
# #### [`arcgis.features`](/python/latest/api-reference/arcgis.features.toc.html)
# * Updates to class initialization methods
# * **New Submodule:**
#   * [`arcgis.features.models`](python/latest/api-reference/arcgis.features.models.html)
#     * [`EstimateResult`](/python/latest/api-reference/arcgis.features.models.html#estimateresult)
#       * Adds class to function as return result when using setting the *estimate* argument to *True* for geoprocessing functions
# * [`FeatureLayer`](/python/latest/api-reference/arcgis.features.toc.html#featurelayer)
#   * [`query_top_features()`](/python/latest/api-reference/arcgis.features.toc.html#arcgis.features.FeatureLayer.query_top_features)
#     * **New parameters:**
#       * *return_count_only*
#   * [`append()`](/python/latest/api-reference/arcgis.features.toc.html#arcgis.features.FeatureLayer.append)
#     * Adds more comprehensive error messaging
#
# #### [`arcgis.features.analysis`](/python/latest/api-reference/arcgis.features.analysis.html)
# * Adds documentation for new return type when *estimate=True* for any functions that support it
#
# #### [`arcgis.features.analyze_patterns`](/python/latest/api-reference/arcgis.features.analyze_patterns.html)
# * **New Functions:**
#   * [`eight_twenty_analysis()`](/python/latest/api-reference/arcgis.features.analyze_patterns.html#eighty-twenty-analysis)
#
# #### [`arcgis.features.managers`](/python/latest/api-reference/arcgis.features.managers.html#)
# * Adds numerous code examples for initializing manager objects and running various operations
# * **New Enumerations:**
#   * [`FilterScopeEnum`](python/latest/api-reference/arcgis.features.managers.html#filterscopeenum)
#   * [`TraversibilityScopeEnum`](python/latest/api-reference/arcgis.features.managers.html#traversabilityscopeenum)
# * [`ParcelFabricManager`](/python/latest/api-reference/arcgis.features.managers.html#parcelfabricmanager)
#   * Adds code examples to reference documentation
# * [`AttachmentManager`](/python/latest/api-reference/arcgis.features.managers.html#attachmentmanager)
#   * [`add()`](/python/latest/api-reference/arcgis.features.managers.html#arcgis.features.managers.AttachmentManager.add)
#     * **New Parameters:**
#       * *gid* - Addresses [**Public Repo Issue 2395**](https://github.com/Esri/arcgis-python-api/issues/2395)
#
# #### [`arcgis.features.enrich_data`](/python/latest/api-reference/arcgis.features.enrich_data.html)
# * [`enrich_layer()`](/python/latest/api-reference/arcgis.features.enrich_data.html#arcgis.features.enrich_data.enrich_layer)
#   * **New Parameters:**
#     * *travel_direction*
#
# #### [`arcgis.raster`](/python/latest/api-reference/arcgis.raster.toc.html#)
# * [`ImageSource`](/python/latest/api-reference/arcgis.raster.toc.html#arcgis.raster.ImageSource)
#   * Updates supported *raster_type_name* list:
#     * Removes *Aerial*
#     * Adds *Altum*, *RedEdge*
#   * Adds support for spatial reference
# * [`RasterCollection`](/python/latest/api-reference/arcgis.raster.toc.html#rastercollection)
#   * [`from_stac_api()`](/python/latest/api-reference/arcgis.raster.toc.html#arcgis.raster.RasterCollection.from_stac_api)
#     * Enhances *context* parameter with 3 new options:
#       * *paginationMode*
#       * *maxItems*
#       * *maxPages*
#     * Enhances *query* parameter so that the *bbox* option accepts *FeatureLayer* and *Geometry* objects
#
# #### [`arcgis.raster.analytics`](/python/latest/api-reference/arcgis.raster.analytics.html#)
# * **New Functions:**
#   * [`derive_stream_as_line()`](/python/latest/api-reference/arcgis.raster.analytics.html#derive-stream-as-line)
#   * [`derive_stream_as_raster()`](/python/latest/api-reference/arcgis.raster.analytics.html#derive-stream-as-raster)
#   * [`geomorphon_landforms()`](/python/latest/api-reference/arcgis.raster.analytics.html#geomorphon-landforms)
#
# #### [`arcgis.raster.functions.gbl`](/python/latest/api-reference/arcgis.raster.functions.gbl.html)
# * Numerous updates to API Reference documentation, particularly adding code examples for many functions
#
# #### [`arcgis.raster.realitymapping`](/python/latest/api-reference/arcgis.raster.realitymapping.html)
# * [ArcGIS Reality Server](https://doc.esri.com/en/arcgis-reality-server/latest/introduction/what-is-reality-server.html) product transitioned from **beta** to General Availability
#   * **note:** Scripts written in 2.4.3 may need modified to accommodate necessary API changes based on overall product updates.
#   * [`Mission`]()
#     * [`reconstruct_surface()`](/python/latest/api-reference/arcgis.raster.realitymapping.html#arcgis.raster._realitymapping_mission.Mission.reconstruct_surface)
#       * Updates to documentation to clarify output types
#       * *RAPID* added as an option for the *quality* argument
#
# #### [`arcgis.network`](/python/latest/api-reference/arcgis.network.toc.html)
# * [`LocateSettings`](/python/latest/api-refernce/arcgis.network.toc.html#locatesettings)
#   * Updates internal format and processing
#
# #### [`arcgis.geometry`](/python/latest/api-reference/arcgis.geometry.html)
# * Adds **deprecation* notice that *Geometry* objects will no longer inherit from the Python *dictionary* object, so bracket notation will no longer be supported
#
# #### [`arcgis.layers`](/python/latest/api-reference/arcgis.layers.toc.html)
# * [Working with Map Service Layers](/python/latest/api-reference/arcgis.layers.toc.html#working-with-map-service-layers)
#   * [`MapImageLayer`](/python/latest/api-reference/arcgis.layers.toc.html#mapimagelayer)
#   * [`TileLayer`](/python/latest/api-reference/arcgis.layers.toc.html#tilelayer)
#   * [`VectorTileLayer`](/python/latest/api-reference/arcgis.layers.toc.html#vectortilelayer)
#   * [`VectorTileLayerManager`](/python/latest/api-reference/arcgis.layers.toc.html#vectortilelayermanager)
#     * [`edit_tile_service()`](/python/latest/api-reference/arcgis.layers.toc.html#arcgis.mapping.VectorTileLayerManager.edit_tile_service)
#
# #### [`arcgis.map`](/python/latest/api-reference/arcgis.map.toc.html)
# * **New Classes:**
#   * [`BaseGroup`](/python/latest/api-reference/arcgis.map.toc.html#basegroup)
#   * [`Map Classes`](/python/latest/api-refernce/arcgis.map.toc.html#map-classes)
#     * [`LayerOptions`](/python/latest/api-refernce/arcgis.map.toc.html#layeroptions)
#   * [Popups](/python/latest/api-reference/arcgis.map.toc.html#popups)
#     * [`PointGeometry`](/python/latest/api-reference/arcgis.map.toc.html#pointgeometry)
#   * [Forms]()
#     * [`FormChoice`](/python/latest/api-reference/arcgis.map.toc.html#formchoice)
#     * [`FormMulipleChoiceInput`](/python/latest/api-reference/arcgis.map.toc.html#formmultiplechoiceinput)
#     * [`FormOtherChoice`](/python/latest/api-reference/arcgis.map.toc.html#formotherchoice)
# * **New API Reference Section:**
#   * [Smart Mapping](/python/latest/api-reference/arcgis.map.toc.html#smart-mapping)
#     * Reorganized module with dataclasses for data validation of inputs and outputs, and standardization for renderer creation. See API Reference for full documentation.
#   * [Smart Mapping Enumerations](/python/latest/api-reference/arcgis.map.toc.html#smart-mapping-enumerations)
#     * New objects to use as input arguments for various Smart Mapping methods. See API Reference for full documentation.
#
# #### [`arcgis.apps`](/python/latest/api-reference/arcgis.apps.html)
# * **New Beta features:**
#   * [`mapshowcase`](/python/latest/api-reference/arcgis.apps.mapshowcase.html)
# * [`workforce`](/python/latest/api-reference/arcgis.apps.workforce.html)
#   * Announces **deprecation** of entire module and notes its removal from the API as Fall 2027
# * [`storymap`](/python/latest/api-reference/arcgis.apps.storymap.html)
#   * **New Classes:**
#     * [`Credits`](python/latest/api-reference/arcgis.apps.storymap.html#credits)
#   * **New Methods:**
#     * `content_info()` - Added to numerous classes within the module for extracting the contents of complex components for easy visualization of content
#       * See [`StoryMap.content_info()`](/python/latest/api-reference/arcgis.apps.storymap.html#arcgis.apps.storymap.story.StoryMap.content_info)
#       * Also added to [`Sidecar`](/python/latest/api-reference/arcgis.apps.storymap.html#arcgis.apps.storymap.story_content.Sidecar), [`MapTour`](/python/latest/api-reference/arcgis.apps.storymap.html#arcgis.apps.storymap.story_content.MapTour), [`Timeline`](/python/latest/api-reference/arcgis.apps.storymap.html#arcgis.apps.storymap.story_content.Timeline), [`Briefing`](/python/latest/api-reference/arcgis.apps.storymap.html#arcgis.apps.storymap.briefing.Briefing)
#   * [`Collection`](/python/latest/api-reference/arcgis.apps.storymap.html#arcgis.apps.storymap.collection.Collection)
#     * [`update_content_info()`](/python/latest/api-reference/arcgis.apps.storymap.html#arcgis.apps.storymap.collection.Collection.update_content_info)
#       * **New Parameters:**
#         * _thumbnail_
# * [`itemgraph`](/python/latest/api-refernce/arcgis.apps.itemgraph.html)
#   * **New Classes:**
#     * [`GraphItemProperty`](/python/latest/api-refernce/arcgis.apps.itemgraph.html#graphitemproperty)
#   * [`create_dependency_graph()`](/python/latest/api-refernce/arcgis.apps.itemgraph.html#create-dependency-graph)
#     * **New Parameters:**
#       * *include_services*
#       * *run_async*
#       * *async_workers*
#     * **ENH-000178652** Adds warnings and enhances function to accommodate ArcGIS Online updates to handling of relationship types
#   * [`load_from_file()`](/python/api-reference/arcgis.apps.itemgraph.html#load-from-file)
#     * **New Parameters:**
#       * *run_async*
#   * [`ItemGraph`](/python/api-reference/arcgis.apps.itemgraph.html#arcgis.apps.itemgraph.ItemGraph)
#     * [`to_knowledge_graph()`](/api-reference/arcgis.apps.itemgraph.html#arcgis.apps.itemgraph.ItemGraph.to_knowledge_graph)
#       * **New Parameters:**
#         * *item_properties*
#
# #### [`arcgis.ai`](/python/latest/api-reference/arcgis.ai.html)
# * Adds note to the reference documentation about current **beta** status and pricing information for when services transition to General Availability
# * **New Functions:**
#   * [`image_extract_text()`](/python/latest/api-reference/arcgis.ai.html#image-extract-text)
#   * [`analyze_file()`](/python/latest/api-reference/arcgis.ai.html#analyze-file)
#   * [`transcribe_audio()`](/python/latest/api-reference/arcgis.ai.html#transcribe-audio)
#   * [`generate_speech()`](/python/latest/api-reference/arcgis.ai.html#generate-speech)
# * **New Dataclasses:**
#   * [`ExtractTextResult`](/python/latest/api-reference/arcgis.ai.html#extracttextresult)
#   * [`TranscribeAudioResult`](/python/latest/api-reference/arcgis.ai.html#transcribeaudioresult)
#   * [`GenerateSpeechResult`](/python/latest/api-reference/arcgis.ai.html#generatespeechresult)
#
# #### [`arcgis.learn`](/python/latest/api-reference/arcgis.learn.toc.html)
# * Adds *ViTAdapter* support to segmentation models for transformer-based backbones
# * [Data Preparation Methods](/python/latest/api-reference/arcgis.learn.toc.html#data-preparation-methods)
#   * [`prepare_data()`](/python/latest/api-reference/arcgis.learn.toc.html#prepare-data)
#     * **New Keyword argument options:**
#       * *valid_path*
#       * *test_path*
#
# #### [`arcgis.graph`](/python/latest/api-reference/arcgis.graph.toc.html)
# * [`KnowledgeGraph`](/python/latest/api-reference/arcgis.graph.html#arcgis.graph.KnowledgeGraph)
#   * **New Functions:**
#     * [`create_replica()`](python/latest/api-reference/arcgis.graph.html#arcgis.graph.KnowledgeGraph.create_replica)
#     * [`unregister_replicas()`](/python/latest/api-reference/arcgis.graph.html#arcgis.graph.KnowledgeGraph.unregister_replicas)
#     * [`get_replica_definition()`](/python/latest/api-reference/arcgis.graph.html#arcgis.graph.KnowledgeGraph.get_replica_definition)
#     * [`synchronize_replica()`](/python/latest/api-reference/arcgis.graph.html#arcgis.graph.KnowledgeGraph.synchronize_replica)
#     * **Beta Helper Functions:**
#       * [`_create_graph_from_replica()`](../guide/part4-create-replicas-and-synchronize-changes/)
#       * [`_update_from_graph_replica()`](../guide/part4-create-replicas-and-synchronize-changes/)
#   * **New Properties:**
#     * [`replicas`](/python/latest/api-reference/arcgis.graph.html#arcgis.graph.KnowledgeGraph.replicas)
#   * **New Parameters:**
#     * [`query_streaming()`](/python/latest/api-reference/arcgis.graph.html#arcgis.graph.KnowledgeGraph.query_streaming)
#       * *as_df*
# * **New Classes:**
#   * [`ReplicaData`](/python/latest/api-reference/arcgis.graph.html#arcgis.graph.ReplicaData)

# %% [markdown]
# ## Fixes
#
# ### [Guides](../)
#
# ### [Samples](/python/samples/)
#
# ### Module Changes
#
# #### [`arcgis.gis`](/python/latest/api-reference/arcgis.gis.toc.html)
# * [`GIS`](/python/latest/api-reference/arcgis.gis.toc.html#gis)
#   * Updates error messaging if entering a non-existent profile for the *profile* argument
# * [`Item`](/python/latest/api-reference/arcgis.gis.toc.html#item)
#   * [`move`](/python/latest/api-reference/arcgis.gis.toc.html#arcgis.gis.Item.move)
#     * [**Public Repo Issue 2532**](https://github.com/Esri/arcgis-python-api/issues/2532)Fixes error when attempting to move item to the *Root* folder
#   * [`update()`](/python/latest/api-reference/arcgis.gis.toc.html#arcgis.gis.Item.update)
#     * Fixes issue when setting properties to None was not properly clearing values
#   * [`copy_feature_layer_collection()`](/python/latest/api-reference/arcgis.gis.toc.html#arcgis.gis.Item.copy_feature_layer_collection)
#     * Fixes *Invalid Definition* error if there are relationships set
# * [`ContentManager`](/python/latest/api-reference/arcgis.gis.toc.html#contentmanager)
#   * [`clone_items()`](/python/latest/api-reference/arcgis.gis.toc.html#arcgis.gis.ContentManager.clone_items)
#     * **ENH-000178319** Updates method to preserve _content_status, delete protection, and migrate _categories_
# * [`User`](/python/latest/api-reference/arcgis.gis.toc.html#user)
#   * Fixes issue in Jupyter Lab notebooks where code completion was not available
# * [`UserManager`](/python/latest/api-reference/arcgis.gis.toc.html#usermanager)
#   * [`search()`](/python/latest/api-reference/arcgis.gis.toc.html#arcgis.gis.UserManager.search)
#     * **BUG-000183570** Fixes issue that more than 10000 users could not be returned by providing a new [`all()`](/python/latest/api-reference/arcgis.gis.toc.html#arcgis.gis.UserManager.all) method
# * [`Folder`](/python/latest/api-reference/arcgis.gis.toc.html#arcgis.gis._impl._content_manager.Folder)
#   * [`add()`](/python/latest/api-reference/arcgis.gis.toc.html#arcgis.gis._impl._content_manager.Folder.add)
#     * **BUG-000186625** Fixes issue where large file uploads were failing to configure valid item from all parts
#     * Fixes `UnboundLocalError for "calculate_upload_size"` when setting *stream=False*
#   * [`list()`](/python/latest/api-reference/arcgis.gis.toc.html#arcgis.gis._impl._content_manager.Folder.list)
#     * Fixes issue iterating over *items* if any orphaned items are in the folder
#
# #### [`arcgis.gis.admin`](/python/latest/api-reference/arcgis.gis.admin.html)
# * [`DeveloperCredential`](/python/latest/api-reference/arcgis.gis.admin.html#developercredential)
#   * [`generate_token()`](/python/latest/api-reference/arcgis.gis.admin.html#arcgis.gis.admin._stokenmgr.DeveloperCredential.generate_token)
#     * Fixes issue where other API Key was deleted when providing the *slot* argument
# * [`LicenseManager`](/python/latest/api-reference/arcgis.gis.admin.html#arcgis.gis.admin.LicenseManager)
#   * [`bundles`](/python/latest/api-reference/arcgis.gis.admin.html#arcgis.gis.admin.LicenseManager.bundles)
#     * [**Public Repo Issue 2519**](https://github.com/Esri/arcgis-python-api/issues/2519) Fixes incorrect results returned when more than 10000 *users* are assigned the bundle
# * [`SecuritySettings`](/python/latest/api-reference/arcgis.gis.admin.html#securitysettings)
#   * [**Public Repo Issue 2518**](https://github.com/Esri/arcgis-python-api/issues/2518)
#     * Fixes error when setting following properties to empty list:
#       * [`allowed_redirect_uris`](/python/latest/api-reference/arcgis.gis.admin.html#arcgis.gis.admin.SecuritySettings.allowed_redirect_uris)
#       * [`allowed_origins`](/python/latest/api-reference/arcgis.gis.admin.html#arcgis.gis.admin.SecuritySettings.allowed_origins)
# * [`Webhook`](/python/latest/api-reference/arcgis.gis.admin.html#webhook)
#   * [`update()`](/python/latest/api-reference/arcgis.gis.admin.html#arcgis.gis.admin.Webhook.update)
#     * **BUG-000186528** Fixes error returned when setting *events* argument to *ALL*
#
# #### [`arcgis.gis.agonb`](/python/latest/api-reference/arcgis.gis.agonb.html)
# * [`Container`](/python/latest/api-reference/arcgis.gis.agonb.html#arcgis.gis.agonb.Container)
#   * [`shutdown()`](/python/latest/api-reference/arcgis.gis.agonb.html#arcgis.gis.agonb.Container.shutdown)
#     * Updates return value
#
# #### [`arcgis.features`](/python/latest/api-reference/arcgis.features.toc.html)
# * [`FeatureLayer`](/python/latest/api-reference/arcgis.features.toc.html#featurelayer)
#   * [`get_unique_values()`](/python/latest/api-reference/arcgis.features.toc.html#arcgis.features.FeatureLayer.get_unique_values)
#     * [**Public Repo Issue 2534**](https://github.com/Esri/arcgis-python-api/issues/2534) Fixes issue where duplicate values were being returned on queries of thousands of features
#   * [`query()`](/python/latest/api-reference/arcgis.features.toc.html#arcgis.features.FeatureLayer.query)
#     * Fixes issue where queried with *return_distinct_values=True* were entering into an infinite loop
# * [`Spatially Enabled DataFrame`](/python/latest/api-reference/arcgis.features.toc.html#geoaccessor) (_GeoAccessor_)
#   * [`to_parquet()`](/python/latest/api-reference/arcgis.features.toc.html#arcgis.features.GeoAccessor.to_parquet)
#     * [**Public Repo Issue 2499**}(https://github.com/Esri/arcgis-python-api/issues/2499) Fixes `TypeError` resulting from improper handling of internal metadata
#   * [`area`](/python/latest/api-reference/arcgis.features.toc.html#arcgis.features.GeoAccessor.area)
#     * Fixes issue where negative values returned for polygons with holes in an environment with *ArcPy*sx
# * [`FeatureSet`](/python/latest/api-reference/arcgis.features.toc.html#featureset)
#   * [`to_geojson()`](/python/latest/api-reference/arcgis.features.toc.html#arcgis.features.FeatureSet.to_geojson)
#   * [**Public Repo Issue #2490**](https://github.com/Esri/arcgis-python-api/issues/2490) Fixes `Key Error` when used on *Multipoint* geometry
#
# #### [`arcgis.features.managers`](/python/latest/api-reference/arcgis.features.managers.html)
# * [`AttachmentManager`](/python/latest/api-reference/arcgis.features.managers.html#attachmentmanager)
#   * [`search()`](/python/latest/api-reference/arcgis.features.managers.html#arcgis.features.managers.AttachmentManager.search)
#     * **BUG-000160369** Fixes issue where _return_metadata=True_ did not return all EXIF information
#   * [`download()`](/python/latest/api-reference/arcgis.features.managers.html#arcgis.features.managers.AttachmentManager.download)
#     * [**Public Repo Issue #2479](https://github.com/Esri/arcgis-python-api/issues/2479) Removes reference to _return_all_ argument from the _attachment_id_ parameter description and updates code to properly return all attachments if no _attachment_id_ is provided
# * [`FeatureLayerCollectionManager`](/python/latest/api-reference/arcgis.features.managers.html#featurelayercollectionmanager)
#   * [`create_view()`](/python/latest/api-reference/arcgis.features.managers.html#arcgis.features.managers.FeatureLayerCollectionManager.create_view)
#     * **BUG-000184553** Fixes issue that if using the *view_layers* argument, the sublayer is removed from the source feature layer item
#
# #### [`arcgis.features.analysis`](/python/latest/api-reference/arcgis.features.analysis.html)
# * Updates API Reference with code examples for numerous functions
#
# #### [`arcgis.raster.realitymapping`](/python/latest/api-reference/arcgis.raster.realitymapping.html)
# * [ArcGIS Reality Server](https://doc.esri.com/en/arcgis-reality-server/latest/introduction/what-is-reality-server.html) product transitioned from **beta** to General Availability
#   * **note:** Scripts written in 2.4.3 may need modified to accommodate necessary API changes based on overall product updates.
#   * [`Project`](/python/latest/api-reference/arcgis.raster.realitymapping.html#project)
#     * Fixes issue when using *AERIAL_DIGITAL* for the *sensor_type* argument
#
# #### [`arcgis.notebook`](/python/latest/api-reference/arcgis.notebook.html)
# * [`NotebookJob`](/python/latest/api-reference/arcgis.notebook.html#notebookjob)
#   * [`running()`](/python/latest/api-reference/arcgis.notebook.html#arcgis.notebook.NotebookJob.running)
#      * Fixes issue on ArcGIS for Kubernetes where a currently running job was returning *False*
#
# #### [`arcgis.geometry`](/python/latest/api-reference/arcgis.geometry.html)
# * Fixes invalid literal `ValueError` when setting *ARCGIS_IO_ENGINE* to *Shapely*
#
# #### [`arcgis.geoprocessing`](/python/latest/api-reference/arcgis.geoprocessing.html)
# * [`import_toolbox()`](/python/latest/api-reference/arcgis.geoprocessing.html#import-toolbox)
#   * Fixes failure to import toolboxes from ArcGIS Online that were created by Model Builder
#
# #### [`arcgis.layers`](/python/latest/api-reference/arcgis.layers.toc.html)
# * [Working with Map Service Layers](/python/latest/api-reference/arcgis.layers.toc.html#working-with-map-service-layers)
#   * [`VectorTileLayerManager`](/python/latest/api-reference/arcgis.layers.toc.html#vectortilelayermanager)
#     * [`edit_tile_service()`](/python/latest/api-reference/arcgis.layers.toc.html#arcgis.mapping.VectorTileLayerManager.edit_tile_service)
#       * Fixes `Invalid Service Definition` error when attempting to update properties
#
# #### [`arcgis.map`](/python/latest/api-reference/arcgis.map.toc.html)
# * Improves performance with load times for:
#   * [`Map`](/python/latest/api-reference/arcgis.map.toc.html#map)
#   * [`Scene`](/python/latest/api-reference/arcgis.map.toc.html#scene)
#
# #### [`arcgis.apps`](/python/latest/api-reference/arcgis.apps.html)
# * [`storymap`](/python/latest/api-reference/arcgis.apps.storymap.html)
#   * [`Storymap`](/python/latest/api-reference/arcgis.apps.storymap.html#storymap)
#     * [`save`](/python/latest/api-reference/arcgis.apps.storymap.html#arcgis.apps.storymap.story.StoryMap.save)
#       * Fixes issue where *typeKeywords* property for items was not being update correctly
# * [`itemgraph`](/python/latest/api-reference/arcgis.apps.itemgraph.html)
#   * [`create_dependency_graph()`](/python/latest/api-reference/arcgis.apps.itemgraph.html#create-dependency-graph)
#     * Updates handling of service URLs to create more accurate and comprehensive graphs
#     * Updates processing to better distinguish between GUID and Item ID values
# * [`expbuilder`](/python/latest/api-reference/arcgis.apps.expbuilder.html)
#   * [`WebExperience`](/python/latest/api-reference/arcgis.apps.expbuilder.html#arcgis.apps.expbuilder.expbuilder.WebExperience)
#     * [`save()`](/python/latest/api-reference/arcgis.apps.expbuilder.html#arcgis.apps.expbuilder.expbuilder.WebExperience.save)
#       * **BUG-000185104** Fixes issue where saving a cloned Experience item carried over the *source-<item_id>* keyword, causing subsequent clones of the original item to fail
#
# #### [`arcgis.learn`](/python/latest/api-reference/arcgis.learn.toc.html)
# * [Automated Machine Learning](/python/latest/api-reference/arcgis.learn.toc.html#automated-machine-learning)
#   * [`AutoML`](/python/latest/api-reference/arcgis.learn.toc.html#automl)
#     * Fixes memory, redundant downloading, and ambiguity issues with Geometry output when using location embeddings
#     * Fixes training failure when using a blob embedding field as explanatory variables
# * [Feature, Tabular, and Timeseries Models](/python/latest/api-refernce/arcgis.learn.toc.html#feature-tabular-and-timeseries-models)
#   * [`TimeSeriesModels`](/python/latest/api-reference/arcgis.learn.toc.html#timeseriesmodel)
#     * [`fit()`](/python/latest/api-refernce/arcgis.learn.toc.html#arcgis.learn.TimeSeriesModel.fit)
#       * Fixes `AttributeError` regarding DynamicCache and *from_legacy_cache* because of change in Transformers in environment
# * [Unstructured Text Models](/python/latest/api-reference/arcgis.learn.toc.html#unstructured-text-models)
#   * Fixes `AttributeError` regarding *batch_encode_plus* when using `fit()` on various methods
#   * [arcgis.learn.text module](/python/latest/api-reference/arcgis.learn.toc.html#arcgis-learn-text-module)
#     * [`EntityRecognizer`](/python/latest/api-reference/arcgis.learn.text.html#entityrecognizer)
#       * Fixes memory issue for Living Atlas DLPK
